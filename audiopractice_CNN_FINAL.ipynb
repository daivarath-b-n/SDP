# %%
### Let's read a sample audio using librosa
import librosa
audio_file_path1='IITG_MV_Phase-I_Speaker_Recognition_Database/100_speaker_Database_Office_Environment/disc_1/IITG_MV_Phase_I_Speaker_Recognition_Database_1.01/Office_Environment/Session1/English_Language/D01/1001_AD01OENC.wav'
audio_file_path2='IITG_MV_Phase-I_Speaker_Recognition_Database/100_speaker_Database_Office_Environment/disc_1/IITG_MV_Phase_I_Speaker_Recognition_Database_1.01/Office_Environment/Session1/Favorite_Language/D01/1001_AD01OKNC.wav'
librosa_audio_data1,librosa_sample_rate1=librosa.load(audio_file_path1)
librosa_audio_data2,librosa_sample_rate2=librosa.load(audio_file_path2)

# %%
### Lets plot the librosa audio data
import matplotlib.pyplot as plt
# Original audio with 1 channel 
plt.figure(figsize=(12, 4))
plt.plot(librosa_audio_data1)
plt.title('English Language Audio')
# Out:
# Text(0.5, 1.0, 'English Language Audio')

# %%
plt.figure(figsize=(12, 4))
plt.plot(librosa_audio_data2)
plt.title('Favorite Language Audio')
# Out:
# Text(0.5, 1.0, 'Favorite Language Audio')

# %%
#### Extracting MFCC's For every audio file
import pandas as pd
import os
import librosa

audio_dataset_path='IITG_MV_Phase-I_Speaker_Recognition_Database/100_speaker_Database_Office_Environment/'
metadata1=pd.read_csv('IITG_MV_Phase-I_Speaker_Recognition_Database/Data/Length_eng.csv')
metadata2=pd.read_csv('IITG_MV_Phase-I_Speaker_Recognition_Database/Data/Length_fav_D01.csv')
metadata3=pd.read_csv('IITG_MV_Phase-I_Speaker_Recognition_Database/Data/Length_fav_H01.csv')
metadata4=pd.read_csv('IITG_MV_Phase-I_Speaker_Recognition_Database/Data/Length_fav_M01.csv')
metadata5=pd.read_csv('IITG_MV_Phase-I_Speaker_Recognition_Database/Data/Length_fav_M02.csv')
metadata6=pd.read_csv('IITG_MV_Phase-I_Speaker_Recognition_Database/Data/Length_fav_T01.csv')
metadata1.head()
# Out:
#      disc                                          Address_1  \
# 0  disc_1  IITG_MV_Phase_I_Speaker_Recognition_Database_1.01
# 1  disc_1  IITG_MV_Phase_I_Speaker_Recognition_Database_1.01
# 2  disc_1  IITG_MV_Phase_I_Speaker_Recognition_Database_1.01
# 3  disc_1  IITG_MV_Phase_I_Speaker_Recognition_Database_1.01
# 4  disc_1  IITG_MV_Phase_I_Speaker_Recognition_Database_1.01
#
#           Environment   Session          Language Recording_Device  \
# 0  Office_Environment  Session1  English_Language              D01
# 1  Office_Environment  Session1  English_Language              D01
# 2  Office_Environment  Session1  English_Language              H01
# 3  Office_Environment  Session1  English_Language              H01
# 4  Office_Environment  Session1  English_Language              M01
#
#            wav_files                                          Address_2  \
# 0  1001_AD01OENC.wav  disc_1\IITG_MV_Phase_I_Speaker_Recognition_Dat...
# 1  1001_AD01OENR.wav  disc_1\IITG_MV_Phase_I_Speaker_Recognition_Dat...
# 2  1001_AH01OENC.wav  disc_1\IITG_MV_Phase_I_Speaker_Recognition_Dat...
# 3  1001_AH01OENR.wav  disc_1\IITG_MV_Phase_I_Speaker_Recognition_Dat...
# 4  1001_AM01OENC.wav  disc_1\IITG_MV_Phase_I_Speaker_Recognition_Dat...
#
#    wav_id
# 0    1001
# 1    1001
# 2    1001
# 3    1001
# 4    1001

# %%
def features_extractor(file_name):
    audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
    
    return mfccs_scaled_features

# %%
import numpy as np
from tqdm import tqdm
extracted_features=[]
for index_num,row in tqdm(metadata1.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path),str(row["disc"]) + '/' ,str(row["Address_1"]) + '/' ,'Office_Environment/' ,str(row["Session"]) + '/', str(row["Language"]) + '/' , str(row["Recording_Device"]) + '/' , str(row["wav_files"]))
    final_class_label1=row["wav_id"]
    final_class_label2=row["wav_files"]
    data=features_extractor(file_name)
    extracted_features.append([data,final_class_label1,final_class_label2])
# Out:
# 2000it [1:21:24,  2.44s/it]

# %%
### converting extracted_features to Pandas dataframe
extracted_features_df=pd.DataFrame(extracted_features,columns=['feature','wav_id','wav_files'])
extracted_features_df.head()
# Out:
#                                              feature  wav_id  \
# 0  [-100.14327, 141.408, -90.44349, 48.122456, -2...    1001
# 1  [-93.400635, 142.4468, -93.61377, 49.428665, -...    1001
# 2  [-312.1448, 139.40472, -2.875815, 17.192211, 3...    1001
# 3  [-317.16547, 152.3441, -16.952948, 13.914769, ...    1001
# 4  [-294.5786, 137.77576, -29.958454, -15.856332,...    1001
#
#            wav_files
# 0  1001_AD01OENC.wav
# 1  1001_AD01OENR.wav
# 2  1001_AH01OENC.wav
# 3  1001_AH01OENR.wav
# 4  1001_AM01OENC.wav

# %%
### Split the dataset into independent and dependent dataset
X_train=np.array(extracted_features_df['feature'].tolist())
y_train=np.array(extracted_features_df['wav_id'].tolist())
# z=np.array(extracted_features_df['D01'].tolist())

# %%
y_train.shape
# Out:
# (2000,)

# %% [markdown]
# TESTING DATASET 1

# %%
import numpy as np
from tqdm import tqdm
extracted_features1=[]
for index_num,row in tqdm(metadata2.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path),str(row["disc"]) + '/' ,str(row["Address_1"]) + '/' ,'Office_Environment/' ,str(row["Session"]) + '/', str(row["Language"]) + '/' , str(row["Recording_Device"]) + '/' , str(row["wav_files"]))
    final_class_label1=row["wav_id"]
    final_class_label2=row["wav_files"]
    data=features_extractor(file_name)
    extracted_features1.append([data,final_class_label1,final_class_label2])
# Out:
# 200it [10:50,  3.25s/it]

# %%
### converting extracted_features to Pandas dataframe
extracted_features1_df=pd.DataFrame(extracted_features1,columns=['feature','wav_id','wav_files'])
extracted_features1_df.head()
# Out:
#                                              feature  wav_id  \
# 0  [-95.667015, 138.71333, -83.94127, 41.06656, -...    1001
# 1  [-320.93527, 118.18691, -61.014763, 32.62668, ...    1001
# 2  [-311.03726, 127.12867, -66.55695, 37.9747, -6...    1002
# 3  [-320.36343, 124.806946, -66.6572, 38.813297, ...    1002
# 4  [-300.52405, 151.92856, -96.720375, 49.4383, -...    1005
#
#            wav_files
# 0  1001_AD01OKNC.wav
# 1  1001_BD01OKNC.wav
# 2  1002_AD01OHNC.wav
# 3  1002_BD01OHNC.wav
# 4  1005_AD01OHNC.wav

# %% [markdown]
# TESTING DATASET 2

# %%
import numpy as np
from tqdm import tqdm
extracted_features2=[]
for index_num,row in tqdm(metadata3.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path),str(row["disc"]) + '/' ,str(row["Address_1"]) + '/' ,'Office_Environment/' ,str(row["Session"]) + '/', str(row["Language"]) + '/' , str(row["Recording_Device"]) + '/' , str(row["wav_files"]))
    final_class_label1=row["wav_id"]
    final_class_label2=row["wav_files"]
    data=features_extractor(file_name)
    extracted_features2.append([data,final_class_label1,final_class_label2])
# Out:
# 200it [10:50,  3.25s/it]

# %%
### converting extracted_features to Pandas dataframe
extracted_features2_df=pd.DataFrame(extracted_features2,columns=['feature','wav_id','wav_files'])
extracted_features2_df.head()
# Out:
#                                              feature  wav_id  \
# 0  [-315.32715, 151.15099, 2.5390542, 7.44357, 21...    1001
# 1  [-321.89377, 140.80576, -4.124968, 15.065647, ...    1001
# 2  [-191.72925, 134.90233, -23.329948, 35.794594,...    1002
# 3  [-191.23888, 132.5427, -23.011148, 42.761574, ...    1002
# 4  [-188.43262, 175.30916, -36.97678, 18.092287, ...    1005
#
#            wav_files
# 0  1001_AH01OKNC.wav
# 1  1001_BH01OKNC.wav
# 2  1002_AH01OHNC.wav
# 3  1002_BH01OHNC.wav
# 4  1005_AH01OHNC.wav

# %% [markdown]
# TESTING DATASET 3

# %%
import numpy as np
from tqdm import tqdm
extracted_features3=[]
for index_num,row in tqdm(metadata4.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path),str(row["disc"]) + '/' ,str(row["Address_1"]) + '/' ,'Office_Environment/' ,str(row["Session"]) + '/', str(row["Language"]) + '/' , str(row["Recording_Device"]) + '/' , str(row["wav_files"]))
    final_class_label1=row["wav_id"]
    final_class_label2=row["wav_files"]
    data=features_extractor(file_name)
    extracted_features3.append([data,final_class_label1,final_class_label2])
# Out:
# 200it [10:32,  3.16s/it]

# %%
### converting extracted_features to Pandas dataframe
extracted_features3_df=pd.DataFrame(extracted_features3,columns=['feature','wav_id','wav_files'])
extracted_features3_df.head()
# Out:
#                                              feature  wav_id  \
# 0  [-309.34497, 149.04422, -25.404354, -25.778412...    1001
# 1  [-308.84, 133.3753, -29.455133, -26.436453, 3....    1001
# 2  [-269.72177, 153.61198, -36.659805, -26.767101...    1002
# 3  [-276.39502, 162.4677, -43.75818, -28.983965, ...    1002
# 4  [-245.24681, 162.62985, -46.36927, -12.7468195...    1005
#
#            wav_files
# 0  1001_AM01OKNC.wav
# 1  1001_BM01OKNC.wav
# 2  1002_AM01OHNC.wav
# 3  1002_BM01OHNC.wav
# 4  1005_AM01OHNC.wav

# %% [markdown]
# TESTING DATASET 4

# %%
import numpy as np
from tqdm import tqdm
extracted_features4=[]
for index_num,row in tqdm(metadata5.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path),str(row["disc"]) + '/' ,str(row["Address_1"]) + '/' ,'Office_Environment/' ,str(row["Session"]) + '/', str(row["Language"]) + '/' , str(row["Recording_Device"]) + '/' , str(row["wav_files"]))
    final_class_label1=row["wav_id"]
    final_class_label2=row["wav_files"]
    data=features_extractor(file_name)
    extracted_features4.append([data,final_class_label1,final_class_label2])
# Out:
# 200it [10:35,  3.18s/it]

# %%
### converting extracted_features to Pandas dataframe
extracted_features4_df=pd.DataFrame(extracted_features4,columns=['feature','wav_id','wav_files'])
extracted_features4_df.head()
# Out:
#                                              feature  wav_id  \
# 0  [-313.50476, 155.73637, 11.445284, -12.976183,...    1001
# 1  [-336.22794, 154.20287, -2.9458504, -15.447759...    1001
# 2  [-298.75952, 158.85913, 2.250538, -15.878189, ...    1002
# 3  [-317.9134, 164.38113, 3.7528334, -12.756791, ...    1002
# 4  [-295.64264, 163.07422, -11.214451, -3.061794,...    1005
#
#            wav_files
# 0  1001_AM02OKNC.wav
# 1  1001_BM02OKNC.wav
# 2  1002_AM02OHNC.wav
# 3  1002_BM02OHNC.wav
# 4  1005_AM02OHNC.wav

# %% [markdown]
# TESTING DATASET 5

# %%
import numpy as np
from tqdm import tqdm
extracted_features5=[]
for index_num,row in tqdm(metadata6.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path),str(row["disc"]) + '/' ,str(row["Address_1"]) + '/' ,'Office_Environment/' ,str(row["Session"]) + '/', str(row["Language"]) + '/' , str(row["Recording_Device"]) + '/' , str(row["wav_files"]))
    final_class_label1=row["wav_id"]
    final_class_label2=row["wav_files"]
    data=features_extractor(file_name)
    extracted_features5.append([data,final_class_label1,final_class_label2])
# Out:
# 200it [10:57,  3.29s/it]

# %%
### converting extracted_features to Pandas dataframe
extracted_features5_df=pd.DataFrame(extracted_features5,columns=['feature','wav_id','wav_files'])
extracted_features5_df.head()
# Out:
#                                              feature  wav_id  \
# 0  [-303.09937, 151.74403, 26.174328, 1.4325701, ...    1001
# 1  [-294.9472, 142.26245, 26.929422, 0.5703501, -...    1001
# 2  [-258.54407, 147.74008, 23.415836, 2.6416948, ...    1002
# 3  [-288.19934, 159.07605, 18.713999, 4.571572, -...    1002
# 4  [-266.62302, 165.36906, 5.0311155, 4.352781, -...    1005
#
#            wav_files
# 0  1001_AT01OKNC.wav
# 1  1001_BT01OKNC.wav
# 2  1002_AT01OHNC.wav
# 3  1002_BT01OHNC.wav
# 4  1005_AT01OHNC.wav

# %%
### Split the dataset into independent and dependent dataset
X_test1=np.array(extracted_features1_df['feature'].tolist())
y_test1=np.array(extracted_features1_df['wav_id'].tolist())

X_test2=np.array(extracted_features2_df['feature'].tolist())
y_test2=np.array(extracted_features2_df['wav_id'].tolist())

X_test3=np.array(extracted_features3_df['feature'].tolist())
y_test3=np.array(extracted_features3_df['wav_id'].tolist())

X_test4=np.array(extracted_features4_df['feature'].tolist())
y_test4=np.array(extracted_features4_df['wav_id'].tolist())

X_test5=np.array(extracted_features5_df['feature'].tolist())
y_test5=np.array(extracted_features5_df['wav_id'].tolist())

# %%
y_test5.shape
# Out:
# (200,)

# %%
## Label Encoding
# y=np.array(pd.get_dummies(y))
## Label Encoder
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
y_train=to_categorical(labelencoder.fit_transform(y_train))
y_test1=to_categorical(labelencoder.fit_transform(y_test1))
y_test2=to_categorical(labelencoder.fit_transform(y_test2))
y_test3=to_categorical(labelencoder.fit_transform(y_test3))
y_test4=to_categorical(labelencoder.fit_transform(y_test4))
y_test5=to_categorical(labelencoder.fit_transform(y_test5))

# %% [markdown]
# MODEL CREATION

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.optimizers import Adam
from sklearn import metrics

# %%
### No of classes
num_labels=y_train.shape[1]

# %% [markdown]
# CNN

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Reshape, Conv1D, Flatten

model1 = Sequential()

# Reshape input for 1D convolution
model1.add(Reshape((40, 1), input_shape=(40,)))

# First convolutional layer
model1.add(Conv1D(100, kernel_size=3, activation='relu'))
# model1.add(Dropout(0.15))

# Second convolutional layer
model1.add(Conv1D(200, kernel_size=3, activation='relu'))
# model1.add(Dropout(0.15))

# Third convolutional layer
model1.add(Conv1D(100, kernel_size=3, activation='relu'))
# model1.add(Dropout(0.15))

# Flatten the output before the final layer
model1.add(Flatten())

# Final layer
model1.add(Dense(num_labels))
model1.add(Activation('softmax'))

# Compile the model as needed
# model.compile(...)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Reshape, Conv1D, Flatten

model2 = Sequential()

# Reshape input for 1D convolution
model2.add(Reshape((40, 1), input_shape=(40,)))

# First convolutional layer
model2.add(Conv1D(100, kernel_size=3, activation='relu'))
# model2.add(Dropout(0.15))

# Second convolutional layer
model2.add(Conv1D(200, kernel_size=3, activation='relu'))
# model2.add(Dropout(0.15))

# Third convolutional layer
model2.add(Conv1D(100, kernel_size=3, activation='relu'))
# model2.add(Dropout(0.15))

# Flatten the output before the final layer
model2.add(Flatten())

# Final layer
model2.add(Dense(num_labels))
model2.add(Activation('softmax'))

# Compile the model as needed
# model.compile(...)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Reshape, Conv1D, Flatten

model3 = Sequential()

# Reshape input for 1D convolution
model3.add(Reshape((40, 1), input_shape=(40,)))

# First convolutional layer
model3.add(Conv1D(100, kernel_size=3, activation='relu'))
# model3.add(Dropout(0.15))

# Second convolutional layer
model3.add(Conv1D(200, kernel_size=3, activation='relu'))
# model3.add(Dropout(0.15))

# Third convolutional layer
model3.add(Conv1D(100, kernel_size=3, activation='relu'))
# model3.add(Dropout(0.15))

# Flatten the output before the final layer
model3.add(Flatten())

# Final layer
model3.add(Dense(num_labels))
model3.add(Activation('softmax'))

# Compile the model as needed
# model.compile(...)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Reshape, Conv1D, Flatten

model4 = Sequential()

# Reshape input for 1D convolution
model4.add(Reshape((40, 1), input_shape=(40,)))

# First convolutional layer
model4.add(Conv1D(100, kernel_size=3, activation='relu'))
# model4.add(Dropout(0.1))

# Second convolutional layer
model4.add(Conv1D(200, kernel_size=3, activation='relu'))
# model4.add(Dropout(0.15))

# Third convolutional layer
model4.add(Conv1D(100, kernel_size=3, activation='relu'))
# model4.add(Dropout(0.15))

# Flatten the output before the final layer
model4.add(Flatten())

# Final layer
model4.add(Dense(num_labels))
model4.add(Activation('softmax'))

# Compile the model as needed
# model.compile(...)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Reshape, Conv1D, Flatten

model5 = Sequential()

# Reshape input for 1D convolution
model5.add(Reshape((40, 1), input_shape=(40,)))

# First convolutional layer
model5.add(Conv1D(100, kernel_size=3, activation='relu'))
# model5.add(Dropout(0.15))

# Second convolutional layer
model5.add(Conv1D(200, kernel_size=3, activation='relu'))
# model5.add(Dropout(0.15))

# Third convolutional layer
model5.add(Conv1D(100, kernel_size=3, activation='relu'))
# model5.add(Dropout(0.15))

# Flatten the output before the final layer
model5.add(Flatten())

# Final layer
model5.add(Dense(num_labels))
model5.add(Activation('softmax'))

# Compile the model as needed
# model.compile(...)

# %%
model1.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')
model2.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')
model3.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')
model4.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')
model5.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 40, 1)             0
#
#  conv1d (Conv1D)             (None, 38, 100)           400
#
#  conv1d_1 (Conv1D)           (None, 36, 200)           60200
#
#  conv1d_2 (Conv1D)           (None, 34, 100)           60100
#
#  flatten (Flatten)           (None, 3400)              0
#
#  dense (Dense)               (None, 100)               340100
#
#  activation (Activation)     (None, 100)               0
#
# =================================================================
# Total params: 460800 (1.76 MB)
# Trainable params: 460800 (1.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
## Trianing my model
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime 

num_epochs = 15
num_batch_size = 32

checkpointer = ModelCheckpoint(filepath='saved_models/audio_classification.hdf5', verbose=1, save_best_only=True)

start = datetime.now()

# history1 = model1.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test1, y_test1), callbacks=[checkpointer], verbose=1)
# history2 = model2.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test2, y_test2), callbacks=[checkpointer], verbose=1)
# history3 = model3.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test3, y_test3), callbacks=[checkpointer], verbose=1)
# history4 = model4.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test4, y_test4), callbacks=[checkpointer], verbose=1)
# history5 = model5.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test5, y_test5), callbacks=[checkpointer], verbose=1)

models = [model1, model2, model3, model4, model5]
X_tests = [X_test1, X_test2, X_test3, X_test4, X_test5]
y_tests = [y_test1, y_test2, y_test3, y_test4, y_test5]

histories = []

for model, X_test, y_test in zip(models, X_tests, y_tests):
    history = model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test, y_test), callbacks=[checkpointer], verbose=1)
    histories.append(history)



duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/15
# 61/63 [============================>.] - ETA: 0s - loss: 4.4917 - accuracy: 0.0456
# Epoch 1: val_loss improved from inf to 3.57575, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 2s 17ms/step - loss: 4.4724 - accuracy: 0.0480 - val_loss: 3.5758 - val_accuracy: 0.1800
# Epoch 2/15
# 16/63 [======>.......................] - ETA: 0s - loss: 3.3069 - accuracy: 0.2246
# E:\Users\vinay\Documents\ML project 1\myenv\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 62/63 [============================>.] - ETA: 0s - loss: 2.6857 - accuracy: 0.3256
# Epoch 2: val_loss improved from 3.57575 to 1.80500, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 1s 11ms/step - loss: 2.6850 - accuracy: 0.3245 - val_loss: 1.8050 - val_accuracy: 0.4600
# Epoch 3/15
# 60/63 [===========================>..] - ETA: 0s - loss: 1.3172 - accuracy: 0.6297
# Epoch 3: val_loss improved from 1.80500 to 1.12816, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 1s 11ms/step - loss: 1.3178 - accuracy: 0.6290 - val_loss: 1.1282 - val_accuracy: 0.6900
# Epoch 4/15
# 63/63 [==============================] - ETA: 0s - loss: 0.7069 - accuracy: 0.7955
# Epoch 4: val_loss improved from 1.12816 to 0.86663, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.7069 - accuracy: 0.7955 - val_loss: 0.8666 - val_accuracy: 0.7500
# Epoch 5/15
# 61/63 [============================>.] - ETA: 0s - loss: 0.4463 - accuracy: 0.8653
# Epoch 5: val_loss improved from 0.86663 to 0.76743, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.4482 - accuracy: 0.8650 - val_loss: 0.7674 - val_accuracy: 0.7800
# Epoch 6/15
# 60/63 [===========================>..] - ETA: 0s - loss: 0.3418 - accuracy: 0.9026
# Epoch 6: val_loss did not improve from 0.76743
# 63/63 [==============================] - 1s 11ms/step - loss: 0.3404 - accuracy: 0.9025 - val_loss: 0.8549 - val_accuracy: 0.7700
# Epoch 7/15
# 60/63 [===========================>..] - ETA: 0s - loss: 0.2796 - accuracy: 0.9208
# Epoch 7: val_loss improved from 0.76743 to 0.39183, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.2767 - accuracy: 0.9210 - val_loss: 0.3918 - val_accuracy: 0.8500
# Epoch 8/15
# 62/63 [============================>.] - ETA: 0s - loss: 0.1160 - accuracy: 0.9672
# Epoch 8: val_loss improved from 0.39183 to 0.38491, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1168 - accuracy: 0.9670 - val_loss: 0.3849 - val_accuracy: 0.8700
# Epoch 9/15
# 59/63 [===========================>..] - ETA: 0s - loss: 0.1376 - accuracy: 0.9624
# Epoch 9: val_loss did not improve from 0.38491
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1349 - accuracy: 0.9630 - val_loss: 0.4242 - val_accuracy: 0.8350
# Epoch 10/15
# 60/63 [===========================>..] - ETA: 0s - loss: 0.0929 - accuracy: 0.9740
# Epoch 10: val_loss improved from 0.38491 to 0.33833, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0926 - accuracy: 0.9735 - val_loss: 0.3383 - val_accuracy: 0.8850
# Epoch 11/15
# 61/63 [============================>.] - ETA: 0s - loss: 0.0727 - accuracy: 0.9805
# Epoch 11: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0715 - accuracy: 0.9810 - val_loss: 0.3901 - val_accuracy: 0.8750
# Epoch 12/15
# 60/63 [===========================>..] - ETA: 0s - loss: 0.0360 - accuracy: 0.9891
# Epoch 12: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0354 - accuracy: 0.9895 - val_loss: 0.3889 - val_accuracy: 0.9150
# Epoch 13/15
# 63/63 [==============================] - ETA: 0s - loss: 0.0337 - accuracy: 0.9900
# Epoch 13: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0337 - accuracy: 0.9900 - val_loss: 0.4008 - val_accuracy: 0.8700
# Epoch 14/15
# 60/63 [===========================>..] - ETA: 0s - loss: 0.0229 - accuracy: 0.9948
# Epoch 14: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0225 - accuracy: 0.9950 - val_loss: 0.5287 - val_accuracy: 0.8700
# Epoch 15/15
# 59/63 [===========================>..] - ETA: 0s - loss: 0.0789 - accuracy: 0.9783
# Epoch 15: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0813 - accuracy: 0.9765 - val_loss: 0.8099 - val_accuracy: 0.8150
# Epoch 1/15
# 58/63 [==========================>...] - ETA: 0s - loss: 4.5221 - accuracy: 0.0453
# Epoch 1: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 13ms/step - loss: 4.4792 - accuracy: 0.0480 - val_loss: 3.4422 - val_accuracy: 0.2300
# Epoch 2/15
# 61/63 [============================>.] - ETA: 0s - loss: 2.7813 - accuracy: 0.3120
# Epoch 2: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 2.7559 - accuracy: 0.3160 - val_loss: 1.5094 - val_accuracy: 0.6350
# Epoch 3/15
# 62/63 [============================>.] - ETA: 0s - loss: 1.3652 - accuracy: 0.6164
# Epoch 3: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 1.3628 - accuracy: 0.6165 - val_loss: 0.7669 - val_accuracy: 0.7800
# Epoch 4/15
# 58/63 [==========================>...] - ETA: 0s - loss: 0.8196 - accuracy: 0.7710
# Epoch 4: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.8143 - accuracy: 0.7720 - val_loss: 0.5823 - val_accuracy: 0.8000
# Epoch 5/15
# 62/63 [============================>.] - ETA: 0s - loss: 0.4862 - accuracy: 0.8624
# Epoch 5: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.4850 - accuracy: 0.8630 - val_loss: 0.4339 - val_accuracy: 0.8500
# Epoch 6/15
# 61/63 [============================>.] - ETA: 0s - loss: 0.3371 - accuracy: 0.8929
# Epoch 6: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.3380 - accuracy: 0.8925 - val_loss: 0.4249 - val_accuracy: 0.8900
# Epoch 7/15
# 61/63 [============================>.] - ETA: 0s - loss: 0.2699 - accuracy: 0.9170
# Epoch 7: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.2657 - accuracy: 0.9185 - val_loss: 0.5048 - val_accuracy: 0.8300
# Epoch 8/15
# 58/63 [==========================>...] - ETA: 0s - loss: 0.2101 - accuracy: 0.9413
# Epoch 8: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.2045 - accuracy: 0.9425 - val_loss: 0.4024 - val_accuracy: 0.8950
# Epoch 9/15
# 62/63 [============================>.] - ETA: 0s - loss: 0.1390 - accuracy: 0.9587
# Epoch 9: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1395 - accuracy: 0.9585 - val_loss: 0.3775 - val_accuracy: 0.8800
# Epoch 10/15
# 62/63 [============================>.] - ETA: 0s - loss: 0.0971 - accuracy: 0.9723
# Epoch 10: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0964 - accuracy: 0.9725 - val_loss: 0.3703 - val_accuracy: 0.8900
# Epoch 11/15
# 62/63 [============================>.] - ETA: 0s - loss: 0.0903 - accuracy: 0.9723
# Epoch 11: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0902 - accuracy: 0.9720 - val_loss: 0.4497 - val_accuracy: 0.8700
# Epoch 12/15
# 60/63 [===========================>..] - ETA: 0s - loss: 0.0951 - accuracy: 0.9729
# Epoch 12: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 12ms/step - loss: 0.0964 - accuracy: 0.9720 - val_loss: 0.3735 - val_accuracy: 0.8650
# Epoch 13/15
# 62/63 [============================>.] - ETA: 0s - loss: 0.1605 - accuracy: 0.9637
# Epoch 13: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1597 - accuracy: 0.9640 - val_loss: 0.4769 - val_accuracy: 0.8700
# Epoch 14/15
# 59/63 [===========================>..] - ETA: 0s - loss: 0.1201 - accuracy: 0.9688
# Epoch 14: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1213 - accuracy: 0.9685 - val_loss: 0.3989 - val_accuracy: 0.8900
# Epoch 15/15
# 58/63 [==========================>...] - ETA: 0s - loss: 0.0848 - accuracy: 0.9768
# Epoch 15: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0818 - accuracy: 0.9775 - val_loss: 0.4510 - val_accuracy: 0.8800
# Epoch 1/15
# 62/63 [============================>.] - ETA: 0s - loss: 4.4298 - accuracy: 0.0580
# Epoch 1: val_loss did not improve from 0.33833
# 63/63 [==============================] - 2s 13ms/step - loss: 4.4257 - accuracy: 0.0595 - val_loss: 3.8445 - val_accuracy: 0.1350
# Epoch 2/15
# 61/63 [============================>.] - ETA: 0s - loss: 2.5703 - accuracy: 0.3555
# Epoch 2: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 2.5632 - accuracy: 0.3585 - val_loss: 2.0060 - val_accuracy: 0.4800
# Epoch 3/15
# 58/63 [==========================>...] - ETA: 0s - loss: 1.1615 - accuracy: 0.6740
# Epoch 3: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 1.1446 - accuracy: 0.6785 - val_loss: 1.5067 - val_accuracy: 0.5400
# Epoch 4/15
# 58/63 [==========================>...] - ETA: 0s - loss: 0.6979 - accuracy: 0.8060
# Epoch 4: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.6885 - accuracy: 0.8095 - val_loss: 1.0631 - val_accuracy: 0.6600
# Epoch 5/15
# 62/63 [============================>.] - ETA: 0s - loss: 0.4302 - accuracy: 0.8649
# Epoch 5: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.4292 - accuracy: 0.8655 - val_loss: 1.0894 - val_accuracy: 0.6450
# Epoch 6/15
# 61/63 [============================>.] - ETA: 0s - loss: 0.2961 - accuracy: 0.9144
# Epoch 6: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.2977 - accuracy: 0.9140 - val_loss: 1.0063 - val_accuracy: 0.6850
# Epoch 7/15
# 61/63 [============================>.] - ETA: 0s - loss: 0.2313 - accuracy: 0.9303
# Epoch 7: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.2294 - accuracy: 0.9305 - val_loss: 0.8990 - val_accuracy: 0.7200
# Epoch 8/15
# 61/63 [============================>.] - ETA: 0s - loss: 0.1451 - accuracy: 0.9595
# Epoch 8: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1447 - accuracy: 0.9595 - val_loss: 0.7109 - val_accuracy: 0.7800
# Epoch 9/15
# 61/63 [============================>.] - ETA: 0s - loss: 0.1113 - accuracy: 0.9698
# Epoch 9: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1096 - accuracy: 0.9705 - val_loss: 0.7240 - val_accuracy: 0.7750
# Epoch 10/15
# 62/63 [============================>.] - ETA: 0s - loss: 0.0981 - accuracy: 0.9753
# Epoch 10: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0978 - accuracy: 0.9755 - val_loss: 0.7172 - val_accuracy: 0.7800
# Epoch 11/15
# 62/63 [============================>.] - ETA: 0s - loss: 0.0797 - accuracy: 0.9753
# Epoch 11: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0791 - accuracy: 0.9755 - val_loss: 0.9764 - val_accuracy: 0.7400
# Epoch 12/15
# 59/63 [===========================>..] - ETA: 0s - loss: 0.0904 - accuracy: 0.9740
# Epoch 12: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0918 - accuracy: 0.9750 - val_loss: 0.8049 - val_accuracy: 0.7650
# Epoch 13/15
# 59/63 [===========================>..] - ETA: 0s - loss: 0.0512 - accuracy: 0.9862
# Epoch 13: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0499 - accuracy: 0.9865 - val_loss: 0.7429 - val_accuracy: 0.7750
# Epoch 14/15
# 58/63 [==========================>...] - ETA: 0s - loss: 0.0526 - accuracy: 0.9887
# Epoch 14: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0516 - accuracy: 0.9880 - val_loss: 1.1641 - val_accuracy: 0.7350
# Epoch 15/15
# 62/63 [============================>.] - ETA: 0s - loss: 0.0778 - accuracy: 0.9814
# Epoch 15: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0773 - accuracy: 0.9815 - val_loss: 0.9327 - val_accuracy: 0.7550
# Epoch 1/15
# 59/63 [===========================>..] - ETA: 0s - loss: 4.5223 - accuracy: 0.0450
# Epoch 1: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 13ms/step - loss: 4.4872 - accuracy: 0.0505 - val_loss: 3.7812 - val_accuracy: 0.2100
# Epoch 2/15
# 60/63 [===========================>..] - ETA: 0s - loss: 2.6224 - accuracy: 0.3531
# Epoch 2: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 2.5914 - accuracy: 0.3585 - val_loss: 2.1931 - val_accuracy: 0.4300
# Epoch 3/15
# 62/63 [============================>.] - ETA: 0s - loss: 1.1263 - accuracy: 0.6835
# Epoch 3: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 1.1293 - accuracy: 0.6835 - val_loss: 1.4550 - val_accuracy: 0.5850
# Epoch 4/15
# 60/63 [===========================>..] - ETA: 0s - loss: 0.6389 - accuracy: 0.8141
# Epoch 4: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.6382 - accuracy: 0.8125 - val_loss: 1.2392 - val_accuracy: 0.6500
# Epoch 5/15
# 60/63 [===========================>..] - ETA: 0s - loss: 0.4240 - accuracy: 0.8667
# Epoch 5: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.4175 - accuracy: 0.8700 - val_loss: 1.1177 - val_accuracy: 0.6850
# Epoch 6/15
# 61/63 [============================>.] - ETA: 0s - loss: 0.3072 - accuracy: 0.9068
# Epoch 6: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.3028 - accuracy: 0.9080 - val_loss: 0.8141 - val_accuracy: 0.7600
# Epoch 7/15
# 62/63 [============================>.] - ETA: 0s - loss: 0.1852 - accuracy: 0.9430
# Epoch 7: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1865 - accuracy: 0.9425 - val_loss: 1.0010 - val_accuracy: 0.7050
# Epoch 8/15
# 58/63 [==========================>...] - ETA: 0s - loss: 0.1387 - accuracy: 0.9585
# Epoch 8: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1399 - accuracy: 0.9565 - val_loss: 1.0731 - val_accuracy: 0.7000
# Epoch 9/15
# 59/63 [===========================>..] - ETA: 0s - loss: 0.1253 - accuracy: 0.9640
# Epoch 9: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1255 - accuracy: 0.9640 - val_loss: 0.8721 - val_accuracy: 0.7500
# Epoch 10/15
# 62/63 [============================>.] - ETA: 0s - loss: 0.0883 - accuracy: 0.9748
# Epoch 10: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0877 - accuracy: 0.9750 - val_loss: 1.1184 - val_accuracy: 0.7450
# Epoch 11/15
# 60/63 [===========================>..] - ETA: 0s - loss: 0.0693 - accuracy: 0.9828
# Epoch 11: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0713 - accuracy: 0.9810 - val_loss: 1.0402 - val_accuracy: 0.7450
# Epoch 12/15
# 60/63 [===========================>..] - ETA: 0s - loss: 0.1075 - accuracy: 0.9703
# Epoch 12: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1046 - accuracy: 0.9705 - val_loss: 1.2073 - val_accuracy: 0.7100
# Epoch 13/15
# 63/63 [==============================] - ETA: 0s - loss: 0.1222 - accuracy: 0.9660
# Epoch 13: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1222 - accuracy: 0.9660 - val_loss: 0.8787 - val_accuracy: 0.7850
# Epoch 14/15
# 62/63 [============================>.] - ETA: 0s - loss: 0.0807 - accuracy: 0.9788
# Epoch 14: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0812 - accuracy: 0.9785 - val_loss: 1.0543 - val_accuracy: 0.7450
# Epoch 15/15
# 63/63 [==============================] - ETA: 0s - loss: 0.0961 - accuracy: 0.9755
# Epoch 15: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0961 - accuracy: 0.9755 - val_loss: 1.0504 - val_accuracy: 0.7350
# Epoch 1/15
# 62/63 [============================>.] - ETA: 0s - loss: 4.5044 - accuracy: 0.0393
# Epoch 1: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 13ms/step - loss: 4.4982 - accuracy: 0.0400 - val_loss: 3.2988 - val_accuracy: 0.2550
# Epoch 2/15
# 60/63 [===========================>..] - ETA: 0s - loss: 2.7216 - accuracy: 0.3234
# Epoch 2: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 2.6973 - accuracy: 0.3280 - val_loss: 1.3310 - val_accuracy: 0.5850
# Epoch 3/15
# 62/63 [============================>.] - ETA: 0s - loss: 1.3473 - accuracy: 0.6225
# Epoch 3: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 1.3438 - accuracy: 0.6235 - val_loss: 0.9131 - val_accuracy: 0.7200
# Epoch 4/15
# 62/63 [============================>.] - ETA: 0s - loss: 0.8338 - accuracy: 0.7611
# Epoch 4: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.8337 - accuracy: 0.7615 - val_loss: 0.7435 - val_accuracy: 0.7650
# Epoch 5/15
# 60/63 [===========================>..] - ETA: 0s - loss: 0.5299 - accuracy: 0.8453
# Epoch 5: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.5312 - accuracy: 0.8455 - val_loss: 0.5219 - val_accuracy: 0.8450
# Epoch 6/15
# 59/63 [===========================>..] - ETA: 0s - loss: 0.3753 - accuracy: 0.8851
# Epoch 6: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3710 - accuracy: 0.8865 - val_loss: 0.5282 - val_accuracy: 0.8250
# Epoch 7/15
# 59/63 [===========================>..] - ETA: 0s - loss: 0.2696 - accuracy: 0.9153
# Epoch 7: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.2663 - accuracy: 0.9170 - val_loss: 0.6689 - val_accuracy: 0.8350
# Epoch 8/15
# 62/63 [============================>.] - ETA: 0s - loss: 0.1933 - accuracy: 0.9446
# Epoch 8: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1924 - accuracy: 0.9445 - val_loss: 0.7247 - val_accuracy: 0.8200
# Epoch 9/15
# 62/63 [============================>.] - ETA: 0s - loss: 0.1209 - accuracy: 0.9657
# Epoch 9: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1203 - accuracy: 0.9660 - val_loss: 0.5356 - val_accuracy: 0.8850
# Epoch 10/15
# 58/63 [==========================>...] - ETA: 0s - loss: 0.1071 - accuracy: 0.9704
# Epoch 10: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1065 - accuracy: 0.9710 - val_loss: 0.6768 - val_accuracy: 0.8500
# Epoch 11/15
# 63/63 [==============================] - ETA: 0s - loss: 0.0663 - accuracy: 0.9785
# Epoch 11: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0663 - accuracy: 0.9785 - val_loss: 0.6074 - val_accuracy: 0.8600
# Epoch 12/15
# 61/63 [============================>.] - ETA: 0s - loss: 0.0736 - accuracy: 0.9810
# Epoch 12: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0738 - accuracy: 0.9810 - val_loss: 0.6896 - val_accuracy: 0.8600
# Epoch 13/15
# 59/63 [===========================>..] - ETA: 0s - loss: 0.1493 - accuracy: 0.9555
# Epoch 13: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1463 - accuracy: 0.9570 - val_loss: 1.1409 - val_accuracy: 0.7900
# Epoch 14/15
# 62/63 [============================>.] - ETA: 0s - loss: 0.1045 - accuracy: 0.9773
# Epoch 14: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1039 - accuracy: 0.9775 - val_loss: 0.9785 - val_accuracy: 0.8350
# Epoch 15/15
# 62/63 [============================>.] - ETA: 0s - loss: 0.1238 - accuracy: 0.9597
# Epoch 15: val_loss did not improve from 0.33833
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1231 - accuracy: 0.9600 - val_loss: 0.8468 - val_accuracy: 0.8000
# Training completed in time:  0:00:56.535169

# %%
##ACCURACY GRAPHS
# List of history objects

model_names = ['D01', 'H01', 'M01', 'M02', 'T01']

# Plot training & validation accuracy values using a for loop
for i, history in enumerate(histories):
    plt.plot(history.history['accuracy'], label='Train ')
    plt.plot(history.history['val_accuracy'], label=f'Test {model_names[i]}')

    plt.title(f'Model accuracy for {model_names[i]}')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='upper left')
    plt.show()

# %%
##LOSS GRAPHS


# Plot training & validation loss values using a for loop
for i, history in enumerate(histories):
    plt.plot(history.history['loss'], label=f'Train - Model {i+1}')
    plt.plot(history.history['val_loss'], label=f'Test - Model {i+1}')
    plt.title('Model loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
A00 = ['D01', 'H01', 'M01', 'M02', 'T01']
models = [model1, model2, model3, model4, model5]
X_tests = [X_test1, X_test2, X_test3, X_test4, X_test5]
y_tests = [y_test1, y_test2, y_test3, y_test4, y_test5]

for i, model in enumerate(models):
    test_accuracy = model.evaluate(X_tests[i], y_tests[i], verbose=0)
    print(A00[i],"::",test_accuracy[1] * 100,"%")
# Out:
# D01 :: 81.49999976158142 %
# H01 :: 87.99999952316284 %
# M01 :: 75.49999952316284 %
# M02 :: 73.50000143051147 %
# T01 :: 80.0000011920929 %

# %%
models = [model1, model2, model3, model4, model5]
X_tests = [X_test1, X_test2, X_test3, X_test4, X_test5]
y_tests = [y_test1, y_test2, y_test3, y_test4, y_test5]
model_names = ['D01', 'H01', 'M01', 'M02', 'T01']

# Iterate over models, X_tests, and y_tests using a for loop
for model, X_test, y_test, model_name in zip(models, X_tests, y_tests, model_names):
    test_accuracy = model.evaluate(X_test, y_test, verbose=0)
    print(f'{model_name}:: {test_accuracy[1] * 100}%')
# Out:
# D01:: 81.49999976158142%
# H01:: 87.99999952316284%
# M01:: 75.49999952316284%
# M02:: 73.50000143051147%
# T01:: 80.0000011920929%

# %% [markdown]
# ##################################################################################################

# %% [markdown]
# TESTTING SOME FILES

# %%
filename = "test_audio_file_1013.wav"
audio, sample_rate = librosa.load(filename, res_type='kaiser_fast')
mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
mfccs_scaled_features = np.mean(mfccs_features.T, axis=0)
mfccs_scaled_features = mfccs_scaled_features.reshape(1, -1)

# Ensure the data type is compatible with the model
mfccs_scaled_features = mfccs_scaled_features.astype(np.float32)  # or np.float64, depending on your model

# Print information
print("MFCCs Scaled Features:", mfccs_scaled_features)
print("Shape of MFCCs Scaled Features:", mfccs_scaled_features.shape)

# Make prediction
predicted_label = model.predict(mfccs_scaled_features)

# Convert predicted label to class
prediction_class = labelencoder.inverse_transform(np.argmax(predicted_label, axis=1))

print("Predicted Label:", predicted_label)
print("Prediction Class:", prediction_class)
# Out:
# MFCCs Scaled Features: [[-2.5040028e+02  1.3209682e+02 -7.8717418e+00  2.9269650e+01
#   -5.5777869e+00  3.0365632e+00 -1.0113774e+01 -8.1464243e+00
#   -8.6004725e+00 -8.8366346e+00 -2.0765049e+00 -4.8153329e+00
#    1.9108819e+00 -7.4406199e+00  4.7980404e+00 -1.3601016e+00
#   -6.0364585e+00  1.7559185e+00 -3.0053513e+00 -3.2974792e-01
#   -3.7073066e+00 -2.0227890e-01 -2.9720175e+00 -3.2463298e+00
#   -1.3024983e+00 -2.1270351e+00  4.6659362e-01 -1.7546346e+00
#    9.4589762e-02 -1.3951576e+00 -1.1924760e+00 -1.6818579e+00
#   -2.1828158e+00 -2.1008353e+00 -2.7897167e+00 -1.3570875e+00
#   -3.0272875e+00 -2.3301322e+00 -2.2447050e+00 -1.3575134e+00]]
# Shape of MFCCs Scaled Features: (1, 40)
# 1/1 [==============================] - 0s 108ms/step
# Predicted Label: [[5.79697098e-13 3.95450229e-03 1.60423183e-16 1.01418848e-07
#   6.42901301e-01 1.51380360e-01 1.13022989e-17 7.98428857e-07
#   3.34184842e-05 1.29601042e-13 6.23908256e-17 8.98575299e-17
#   2.11420332e-13 1.17433019e-09 3.08111758e-08 1.25732346e-12
#   2.22359013e-04 5.59548718e-12 3.67625762e-05 2.84994357e-15
#   2.87573414e-18 1.81358567e-10 1.96473832e-14 2.82386509e-06
#   1.05271205e-07 2.99886296e-11 3.87773952e-07 5.58758074e-06
#   1.61958363e-11 2.21593922e-07 3.37459944e-08 4.08051601e-05
#   1.87314163e-05 6.52074483e-09 1.08433371e-04 1.88445613e-11
#   3.36221165e-05 8.98838266e-08 5.72285448e-11 9.66225450e-12
#   1.04664934e-04 1.77023662e-06 1.89183641e-10 8.51240533e-04
#   3.81052047e-07 1.03490939e-03 9.51717701e-03 1.32407877e-07
#   7.51643725e-08 1.76627352e-10 5.29019744e-05 1.28872529e-07
#   4.79280061e-07 4.04844468e-05 4.48991155e-09 3.28102348e-18
#   1.15677176e-10 6.10675386e-08 2.07482958e-06 3.74316699e-07
#   2.12599827e-10 8.19078849e-09 2.02914598e-05 2.70878076e-08
#   1.93984981e-10 2.68418621e-12 1.35888953e-08 1.27439407e-07
#   1.69105539e-12 3.60060885e-13 2.36172304e-02 8.48800369e-07
#   1.94484028e-06 1.27752766e-01 7.80803617e-08 1.76214989e-08
#   1.76589992e-06 3.82563174e-02 1.19452113e-06 3.66783333e-08
#   2.98032931e-12 6.36539039e-17 3.89194243e-19 2.00832178e-25
#   4.28348534e-28 5.08062053e-27 1.02798143e-21 4.19854446e-17
#   3.96236266e-13 1.63766187e-19 4.13957032e-19 1.61106825e-18
#   1.21571769e-18 8.10561472e-22 1.10497142e-16 2.82834196e-19
#   5.87549783e-15 2.32359670e-25 3.54688311e-13 2.60956823e-20]]
# Prediction Class: [1012]
