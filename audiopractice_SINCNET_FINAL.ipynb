# %%
### Let's read a sample audio using librosa
import librosa
audio_file_path1='IITG_MV_Phase-I_Speaker_Recognition_Database/100_speaker_Database_Office_Environment/disc_1/IITG_MV_Phase_I_Speaker_Recognition_Database_1.01/Office_Environment/Session1/English_Language/D01/1001_AD01OENC.wav'
audio_file_path2='IITG_MV_Phase-I_Speaker_Recognition_Database/100_speaker_Database_Office_Environment/disc_1/IITG_MV_Phase_I_Speaker_Recognition_Database_1.01/Office_Environment/Session1/Favorite_Language/D01/1001_AD01OKNC.wav'
librosa_audio_data1,librosa_sample_rate1=librosa.load(audio_file_path1)
librosa_audio_data2,librosa_sample_rate2=librosa.load(audio_file_path2)

# %%
### Lets plot the librosa audio data
import matplotlib.pyplot as plt
# Original audio with 1 channel 
plt.figure(figsize=(12, 4))
plt.plot(librosa_audio_data1)
plt.title('English Language Audio')
# Out:
# Text(0.5, 1.0, 'English Language Audio')

# %%
plt.figure(figsize=(12, 4))
plt.plot(librosa_audio_data2)
plt.title('Favorite Language Audio')
# Out:
# Text(0.5, 1.0, 'Favorite Language Audio')

# %%
#### Extracting MFCC's For every audio file
import pandas as pd
import os
import librosa

audio_dataset_path='IITG_MV_Phase-I_Speaker_Recognition_Database/100_speaker_Database_Office_Environment/'
metadata1=pd.read_csv('IITG_MV_Phase-I_Speaker_Recognition_Database/Data/Length_eng.csv')
metadata2=pd.read_csv('IITG_MV_Phase-I_Speaker_Recognition_Database/Data/Length_fav_D01.csv')
metadata3=pd.read_csv('IITG_MV_Phase-I_Speaker_Recognition_Database/Data/Length_fav_H01.csv')
metadata4=pd.read_csv('IITG_MV_Phase-I_Speaker_Recognition_Database/Data/Length_fav_M01.csv')
metadata5=pd.read_csv('IITG_MV_Phase-I_Speaker_Recognition_Database/Data/Length_fav_M02.csv')
metadata6=pd.read_csv('IITG_MV_Phase-I_Speaker_Recognition_Database/Data/Length_fav_T01.csv')
metadata1.head()
# Out:
#      disc                                          Address_1  \
# 0  disc_1  IITG_MV_Phase_I_Speaker_Recognition_Database_1.01
# 1  disc_1  IITG_MV_Phase_I_Speaker_Recognition_Database_1.01
# 2  disc_1  IITG_MV_Phase_I_Speaker_Recognition_Database_1.01
# 3  disc_1  IITG_MV_Phase_I_Speaker_Recognition_Database_1.01
# 4  disc_1  IITG_MV_Phase_I_Speaker_Recognition_Database_1.01
#
#           Environment   Session          Language Recording_Device  \
# 0  Office_Environment  Session1  English_Language              D01
# 1  Office_Environment  Session1  English_Language              D01
# 2  Office_Environment  Session1  English_Language              H01
# 3  Office_Environment  Session1  English_Language              H01
# 4  Office_Environment  Session1  English_Language              M01
#
#            wav_files                                          Address_2  \
# 0  1001_AD01OENC.wav  disc_1\IITG_MV_Phase_I_Speaker_Recognition_Dat...
# 1  1001_AD01OENR.wav  disc_1\IITG_MV_Phase_I_Speaker_Recognition_Dat...
# 2  1001_AH01OENC.wav  disc_1\IITG_MV_Phase_I_Speaker_Recognition_Dat...
# 3  1001_AH01OENR.wav  disc_1\IITG_MV_Phase_I_Speaker_Recognition_Dat...
# 4  1001_AM01OENC.wav  disc_1\IITG_MV_Phase_I_Speaker_Recognition_Dat...
#
#    wav_id
# 0    1001
# 1    1001
# 2    1001
# 3    1001
# 4    1001

# %%
def features_extractor(file_name):
    audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
    
    return mfccs_scaled_features

# %%
import numpy as np
from tqdm import tqdm
extracted_features=[]
for index_num,row in tqdm(metadata1.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path),str(row["disc"]) + '/' ,str(row["Address_1"]) + '/' ,'Office_Environment/' ,str(row["Session"]) + '/', str(row["Language"]) + '/' , str(row["Recording_Device"]) + '/' , str(row["wav_files"]))
    final_class_label1=row["wav_id"]
    final_class_label2=row["wav_files"]
    data=features_extractor(file_name)
    extracted_features.append([data,final_class_label1,final_class_label2])
# Out:
# 2000it [1:21:05,  2.43s/it]

# %%
### converting extracted_features to Pandas dataframe
extracted_features_df=pd.DataFrame(extracted_features,columns=['feature','wav_id','wav_files'])
extracted_features_df.head()
# Out:
#                                              feature  wav_id  \
# 0  [-100.14327, 141.408, -90.44349, 48.122456, -2...    1001
# 1  [-93.400635, 142.4468, -93.61377, 49.428665, -...    1001
# 2  [-312.1448, 139.40472, -2.875815, 17.192211, 3...    1001
# 3  [-317.16547, 152.3441, -16.952948, 13.914769, ...    1001
# 4  [-294.5786, 137.77576, -29.958454, -15.856332,...    1001
#
#            wav_files
# 0  1001_AD01OENC.wav
# 1  1001_AD01OENR.wav
# 2  1001_AH01OENC.wav
# 3  1001_AH01OENR.wav
# 4  1001_AM01OENC.wav

# %%
### Split the dataset into independent and dependent dataset
X_train=np.array(extracted_features_df['feature'].tolist())
y_train=np.array(extracted_features_df['wav_id'].tolist())
# z=np.array(extracted_features_df['D01'].tolist())

# %%
y_train.shape
# Out:
# (2000,)

# %% [markdown]
# TESTING DATASET 1

# %%
import numpy as np
from tqdm import tqdm
extracted_features1=[]
for index_num,row in tqdm(metadata2.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path),str(row["disc"]) + '/' ,str(row["Address_1"]) + '/' ,'Office_Environment/' ,str(row["Session"]) + '/', str(row["Language"]) + '/' , str(row["Recording_Device"]) + '/' , str(row["wav_files"]))
    final_class_label1=row["wav_id"]
    final_class_label2=row["wav_files"]
    data=features_extractor(file_name)
    extracted_features1.append([data,final_class_label1,final_class_label2])
# Out:
# 200it [10:51,  3.26s/it]

# %%
### converting extracted_features to Pandas dataframe
extracted_features1_df=pd.DataFrame(extracted_features1,columns=['feature','wav_id','wav_files'])
extracted_features1_df.head()
# Out:
#                                              feature  wav_id  \
# 0  [-95.667015, 138.71333, -83.94127, 41.06656, -...    1001
# 1  [-320.93527, 118.18691, -61.014763, 32.62668, ...    1001
# 2  [-311.03726, 127.12867, -66.55695, 37.9747, -6...    1002
# 3  [-320.36343, 124.806946, -66.6572, 38.813297, ...    1002
# 4  [-300.52405, 151.92856, -96.720375, 49.4383, -...    1005
#
#            wav_files
# 0  1001_AD01OKNC.wav
# 1  1001_BD01OKNC.wav
# 2  1002_AD01OHNC.wav
# 3  1002_BD01OHNC.wav
# 4  1005_AD01OHNC.wav

# %% [markdown]
# TESTING DATASET 2

# %%
import numpy as np
from tqdm import tqdm
extracted_features2=[]
for index_num,row in tqdm(metadata3.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path),str(row["disc"]) + '/' ,str(row["Address_1"]) + '/' ,'Office_Environment/' ,str(row["Session"]) + '/', str(row["Language"]) + '/' , str(row["Recording_Device"]) + '/' , str(row["wav_files"]))
    final_class_label1=row["wav_id"]
    final_class_label2=row["wav_files"]
    data=features_extractor(file_name)
    extracted_features2.append([data,final_class_label1,final_class_label2])
# Out:
# 200it [12:35,  3.78s/it]

# %%
### converting extracted_features to Pandas dataframe
extracted_features2_df=pd.DataFrame(extracted_features2,columns=['feature','wav_id','wav_files'])
extracted_features2_df.head()
# Out:
#                                              feature  wav_id  \
# 0  [-315.32715, 151.15099, 2.5390542, 7.44357, 21...    1001
# 1  [-321.89377, 140.80576, -4.124968, 15.065647, ...    1001
# 2  [-191.72925, 134.90233, -23.329948, 35.794594,...    1002
# 3  [-191.23888, 132.5427, -23.011148, 42.761574, ...    1002
# 4  [-188.43262, 175.30916, -36.97678, 18.092287, ...    1005
#
#            wav_files
# 0  1001_AH01OKNC.wav
# 1  1001_BH01OKNC.wav
# 2  1002_AH01OHNC.wav
# 3  1002_BH01OHNC.wav
# 4  1005_AH01OHNC.wav

# %% [markdown]
# TESTING DATASET 3

# %%
import numpy as np
from tqdm import tqdm
extracted_features3=[]
for index_num,row in tqdm(metadata4.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path),str(row["disc"]) + '/' ,str(row["Address_1"]) + '/' ,'Office_Environment/' ,str(row["Session"]) + '/', str(row["Language"]) + '/' , str(row["Recording_Device"]) + '/' , str(row["wav_files"]))
    final_class_label1=row["wav_id"]
    final_class_label2=row["wav_files"]
    data=features_extractor(file_name)
    extracted_features3.append([data,final_class_label1,final_class_label2])
# Out:
# 200it [12:20,  3.70s/it]

# %%
### converting extracted_features to Pandas dataframe
extracted_features3_df=pd.DataFrame(extracted_features3,columns=['feature','wav_id','wav_files'])
extracted_features3_df.head()
# Out:
#                                              feature  wav_id  \
# 0  [-309.34497, 149.04422, -25.404354, -25.778412...    1001
# 1  [-308.84, 133.3753, -29.455133, -26.436453, 3....    1001
# 2  [-269.72177, 153.61198, -36.659805, -26.767101...    1002
# 3  [-276.39502, 162.4677, -43.75818, -28.983965, ...    1002
# 4  [-245.24681, 162.62985, -46.36927, -12.7468195...    1005
#
#            wav_files
# 0  1001_AM01OKNC.wav
# 1  1001_BM01OKNC.wav
# 2  1002_AM01OHNC.wav
# 3  1002_BM01OHNC.wav
# 4  1005_AM01OHNC.wav

# %% [markdown]
# TESTING DATASET 4

# %%
import numpy as np
from tqdm import tqdm
extracted_features4=[]
for index_num,row in tqdm(metadata5.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path),str(row["disc"]) + '/' ,str(row["Address_1"]) + '/' ,'Office_Environment/' ,str(row["Session"]) + '/', str(row["Language"]) + '/' , str(row["Recording_Device"]) + '/' , str(row["wav_files"]))
    final_class_label1=row["wav_id"]
    final_class_label2=row["wav_files"]
    data=features_extractor(file_name)
    extracted_features4.append([data,final_class_label1,final_class_label2])
# Out:
# 200it [10:26,  3.13s/it]

# %%
### converting extracted_features to Pandas dataframe
extracted_features4_df=pd.DataFrame(extracted_features4,columns=['feature','wav_id','wav_files'])
extracted_features4_df.head()
# Out:
#                                              feature  wav_id  \
# 0  [-313.50476, 155.73637, 11.445284, -12.976183,...    1001
# 1  [-336.22794, 154.20287, -2.9458504, -15.447759...    1001
# 2  [-298.75952, 158.85913, 2.250538, -15.878189, ...    1002
# 3  [-317.9134, 164.38113, 3.7528334, -12.756791, ...    1002
# 4  [-295.64264, 163.07422, -11.214451, -3.061794,...    1005
#
#            wav_files
# 0  1001_AM02OKNC.wav
# 1  1001_BM02OKNC.wav
# 2  1002_AM02OHNC.wav
# 3  1002_BM02OHNC.wav
# 4  1005_AM02OHNC.wav

# %% [markdown]
# TESTING DATASET 5

# %%
import numpy as np
from tqdm import tqdm
extracted_features5=[]
for index_num,row in tqdm(metadata6.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path),str(row["disc"]) + '/' ,str(row["Address_1"]) + '/' ,'Office_Environment/' ,str(row["Session"]) + '/', str(row["Language"]) + '/' , str(row["Recording_Device"]) + '/' , str(row["wav_files"]))
    final_class_label1=row["wav_id"]
    final_class_label2=row["wav_files"]
    data=features_extractor(file_name)
    extracted_features5.append([data,final_class_label1,final_class_label2])
# Out:
# 200it [10:42,  3.21s/it]

# %%
### converting extracted_features to Pandas dataframe
extracted_features5_df=pd.DataFrame(extracted_features5,columns=['feature','wav_id','wav_files'])
extracted_features5_df.head()
# Out:
#                                              feature  wav_id  \
# 0  [-303.09937, 151.74403, 26.174328, 1.4325701, ...    1001
# 1  [-294.9472, 142.26245, 26.929422, 0.5703501, -...    1001
# 2  [-258.54407, 147.74008, 23.415836, 2.6416948, ...    1002
# 3  [-288.19934, 159.07605, 18.713999, 4.571572, -...    1002
# 4  [-266.62302, 165.36906, 5.0311155, 4.352781, -...    1005
#
#            wav_files
# 0  1001_AT01OKNC.wav
# 1  1001_BT01OKNC.wav
# 2  1002_AT01OHNC.wav
# 3  1002_BT01OHNC.wav
# 4  1005_AT01OHNC.wav

# %%
### Split the dataset into independent and dependent dataset
X_test1=np.array(extracted_features1_df['feature'].tolist())
y_test1=np.array(extracted_features1_df['wav_id'].tolist())

X_test2=np.array(extracted_features2_df['feature'].tolist())
y_test2=np.array(extracted_features2_df['wav_id'].tolist())

X_test3=np.array(extracted_features3_df['feature'].tolist())
y_test3=np.array(extracted_features3_df['wav_id'].tolist())

X_test4=np.array(extracted_features4_df['feature'].tolist())
y_test4=np.array(extracted_features4_df['wav_id'].tolist())

X_test5=np.array(extracted_features5_df['feature'].tolist())
y_test5=np.array(extracted_features5_df['wav_id'].tolist())

# %%
y_test5.shape
# Out:
# (200,)

# %%
## Label Encoding
# y=np.array(pd.get_dummies(y))
## Label Encoder
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
y_train=to_categorical(labelencoder.fit_transform(y_train))
y_test1=to_categorical(labelencoder.fit_transform(y_test1))
y_test2=to_categorical(labelencoder.fit_transform(y_test2))
y_test3=to_categorical(labelencoder.fit_transform(y_test3))
y_test4=to_categorical(labelencoder.fit_transform(y_test4))
y_test5=to_categorical(labelencoder.fit_transform(y_test5))

# %%
y_test5.shape
# Out:
# (200, 100)

# %% [markdown]
# MODEL CREATION

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.optimizers import Adam
from sklearn import metrics

# %%
### No of classes
num_labels=y_train.shape[1]

# %% [markdown]
# SINCNET

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Reshape, Dropout
from sincnet_tensorflow import SincConv1D
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Reshape, Conv1D, Flatten

model1 = Sequential()

# Reshape input for 1D convolution
model1.add(Reshape((40, 1), input_shape=(40,)))

# First SincConv layer
model1.add(SincConv1D(N_filt=100, Filt_dim=151, fs=22050))
# model.add(Dropout(0.5))

# # Second SincConv layer
# model.add(SincConv1D(N_filt=100, Filt_dim=101, fs=22050))
# model.add(Dropout(0.5))

# # Third SincConv layer
# model.add(SincConv1D(N_filt=100, Filt_dim=101, fs=22050))
# model.add(Dropout(0.5))

# Flatten the output before the final layer
model1.add(Flatten())

# Final layer
model1.add(Dense(num_labels, activation='softmax'))

# Compile the model as needed
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model2 = Sequential()

# Reshape input for 1D convolution
model2.add(Reshape((40, 1), input_shape=(40,)))

# First SincConv layer
model2.add(SincConv1D(N_filt=100, Filt_dim=151, fs=22050))
# model.add(Dropout(0.5))

# Flatten the output before the final layer
model2.add(Flatten())

# Final layer
model2.add(Dense(num_labels, activation='softmax'))

# Compile the model as needed
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model3 = Sequential()

# Reshape input for 1D convolution
model3.add(Reshape((40, 1), input_shape=(40,)))

# First SincConv layer
model3.add(SincConv1D(N_filt=100, Filt_dim=151, fs=22050))
# model.add(Dropout(0.5))

# Flatten the output before the final layer
model3.add(Flatten())

# Final layer
model3.add(Dense(num_labels, activation='softmax'))

# Compile the model as needed
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model4 = Sequential()

# Reshape input for 1D convolution
model4.add(Reshape((40, 1), input_shape=(40,)))

# First SincConv layer
model4.add(SincConv1D(N_filt=100, Filt_dim=151, fs=22050))
# model.add(Dropout(0.5))

# Flatten the output before the final layer
model4.add(Flatten())

# Final layer
model4.add(Dense(num_labels, activation='softmax'))

# Compile the model as needed
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model5 = Sequential()

# Reshape input for 1D convolution
model5.add(Reshape((40, 1), input_shape=(40,)))

# First SincConv layer
model5.add(SincConv1D(N_filt=100, Filt_dim=151, fs=22050))
# model.add(Dropout(0.5))

# Flatten the output before the final layer
model5.add(Flatten())

# Final layer
model5.add(Dense(num_labels, activation='softmax'))

# Compile the model as needed
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model1.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')
model2.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')
model3.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')
model4.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')
model5.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')

# %%
## Trianing my model
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime 

num_epochs = 100
num_batch_size = 32

checkpointer = ModelCheckpoint(filepath='saved_models/audio_classification.hdf5', verbose=1, save_best_only=True)

start = datetime.now()

# history1 = model1.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test1, y_test1), callbacks=[checkpointer], verbose=1)
# history2 = model2.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test2, y_test2), callbacks=[checkpointer], verbose=1)
# history3 = model3.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test3, y_test3), callbacks=[checkpointer], verbose=1)
# history4 = model4.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test4, y_test4), callbacks=[checkpointer], verbose=1)
# history5 = model5.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test5, y_test5), callbacks=[checkpointer], verbose=1)

models = [model1, model2, model3, model4, model5]
X_tests = [X_test1, X_test2, X_test3, X_test4, X_test5]
y_tests = [y_test1, y_test2, y_test3, y_test4, y_test5]

histories = []

for model, X_test, y_test in zip(models, X_tests, y_tests):
    history = model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test, y_test), callbacks=[checkpointer], verbose=1)
    histories.append(history)



duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/100
# 52/63 [=======================>......] - ETA: 0s - loss: 108.7734 - accuracy: 0.0108
# Epoch 1: val_loss improved from inf to 85.85870, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 2s 6ms/step - loss: 100.5331 - accuracy: 0.0130 - val_loss: 85.8587 - val_accuracy: 0.0050
# Epoch 2/100
# 43/63 [===================>..........] - ETA: 0s - loss: 51.7693 - accuracy: 0.0182
# E:\Users\vinay\Documents\ML project 1\myenv\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss improved from 85.85870 to 54.00694, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 48.8096 - accuracy: 0.0180 - val_loss: 54.0069 - val_accuracy: 0.0100
# Epoch 3/100
# 43/63 [===================>..........] - ETA: 0s - loss: 38.8190 - accuracy: 0.0189
# Epoch 3: val_loss improved from 54.00694 to 43.93835, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 37.5821 - accuracy: 0.0220 - val_loss: 43.9384 - val_accuracy: 0.0300
# Epoch 4/100
# 51/63 [=======================>......] - ETA: 0s - loss: 32.3260 - accuracy: 0.0331
# Epoch 4: val_loss improved from 43.93835 to 36.34491, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 31.1708 - accuracy: 0.0350 - val_loss: 36.3449 - val_accuracy: 0.0300
# Epoch 5/100
# 58/63 [==========================>...] - ETA: 0s - loss: 26.3647 - accuracy: 0.0329
# Epoch 5: val_loss improved from 36.34491 to 32.34354, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 26.3149 - accuracy: 0.0315 - val_loss: 32.3435 - val_accuracy: 0.0450
# Epoch 6/100
# 58/63 [==========================>...] - ETA: 0s - loss: 22.9781 - accuracy: 0.0533
# Epoch 6: val_loss improved from 32.34354 to 22.33734, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 22.8130 - accuracy: 0.0515 - val_loss: 22.3373 - val_accuracy: 0.0650
# Epoch 7/100
# 59/63 [===========================>..] - ETA: 0s - loss: 20.3244 - accuracy: 0.0540
# Epoch 7: val_loss did not improve from 22.33734
# 63/63 [==============================] - 0s 2ms/step - loss: 20.2747 - accuracy: 0.0520 - val_loss: 26.1253 - val_accuracy: 0.0400
# Epoch 8/100
# 62/63 [============================>.] - ETA: 0s - loss: 18.3263 - accuracy: 0.0655
# Epoch 8: val_loss did not improve from 22.33734
# 63/63 [==============================] - 0s 2ms/step - loss: 18.2994 - accuracy: 0.0655 - val_loss: 22.3416 - val_accuracy: 0.0350
# Epoch 20/100
# 47/63 [=====================>........] - ETA: 0s - loss: 7.1674 - accuracy: 0.1908
# Epoch 20: val_loss did not improve from 8.57971
# 63/63 [==============================] - 0s 3ms/step - loss: 6.9720 - accuracy: 0.1990 - val_loss: 11.6593 - val_accuracy: 0.0800
# Epoch 21/100
# 53/63 [========================>.....] - ETA: 0s - loss: 6.2319 - accuracy: 0.2335
# Epoch 21: val_loss did not improve from 8.57971
# 63/63 [==============================] - 0s 2ms/step - loss: 6.2710 - accuracy: 0.2270 - val_loss: 9.5091 - val_accuracy: 0.1450
# Epoch 22/100
# 57/63 [==========================>...] - ETA: 0s - loss: 5.9160 - accuracy: 0.2297
# Epoch 22: val_loss improved from 8.57971 to 7.46397, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 5.8830 - accuracy: 0.2330 - val_loss: 7.4640 - val_accuracy: 0.1500
# Epoch 23/100
# 57/63 [==========================>...] - ETA: 0s - loss: 5.1812 - accuracy: 0.2500
# Epoch 23: val_loss improved from 7.46397 to 7.19360, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 5.1420 - accuracy: 0.2555 - val_loss: 7.1936 - val_accuracy: 0.1450
# Epoch 24/100
# 57/63 [==========================>...] - ETA: 0s - loss: 4.8402 - accuracy: 0.2911
# Epoch 24: val_loss improved from 7.19360 to 7.08240, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 2ms/step - loss: 4.8984 - accuracy: 0.2880 - val_loss: 7.0824 - val_accuracy: 0.1750
# Epoch 25/100
# 57/63 [==========================>...] - ETA: 0s - loss: 4.8652 - accuracy: 0.2593
# Epoch 25: val_loss did not improve from 7.08240
# 63/63 [==============================] - 0s 2ms/step - loss: 4.9412 - accuracy: 0.2625 - val_loss: 7.4919 - val_accuracy: 0.1850
# Epoch 26/100
# 59/63 [===========================>..] - ETA: 0s - loss: 4.8217 - accuracy: 0.2765
# Epoch 26: val_loss did not improve from 7.08240
# 63/63 [==============================] - 0s 2ms/step - loss: 4.8743 - accuracy: 0.2725 - val_loss: 8.0813 - val_accuracy: 0.1550
# Epoch 27/100
# 57/63 [==========================>...] - ETA: 0s - loss: 4.4923 - accuracy: 0.2889
# Epoch 27: val_loss improved from 7.08240 to 5.23218, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 4.4055 - accuracy: 0.2910 - val_loss: 5.2322 - val_accuracy: 0.2350
# Epoch 28/100
# 58/63 [==========================>...] - ETA: 0s - loss: 4.1100 - accuracy: 0.3055
# Epoch 28: val_loss did not improve from 5.23218
# 63/63 [==============================] - 0s 2ms/step - loss: 4.0696 - accuracy: 0.3070 - val_loss: 7.1842 - val_accuracy: 0.2000
# Epoch 29/100
# 58/63 [==========================>...] - ETA: 0s - loss: 3.5461 - accuracy: 0.3594
# Epoch 29: val_loss did not improve from 5.23218
# 63/63 [==============================] - 0s 2ms/step - loss: 3.6261 - accuracy: 0.3510 - val_loss: 6.2579 - val_accuracy: 0.1750
# Epoch 30/100
# 58/63 [==========================>...] - ETA: 0s - loss: 3.4313 - accuracy: 0.3513
# Epoch 30: val_loss improved from 5.23218 to 4.75390, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 3.4839 - accuracy: 0.3475 - val_loss: 4.7539 - val_accuracy: 0.2500
# Epoch 31/100
# 59/63 [===========================>..] - ETA: 0s - loss: 3.3620 - accuracy: 0.3559
# Epoch 31: val_loss did not improve from 4.75390
# 63/63 [==============================] - 0s 3ms/step - loss: 3.3769 - accuracy: 0.3545 - val_loss: 5.5234 - val_accuracy: 0.1650
# Epoch 32/100
# 55/63 [=========================>....] - ETA: 0s - loss: 2.9853 - accuracy: 0.3960
# Epoch 32: val_loss improved from 4.75390 to 4.50419, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 3.0469 - accuracy: 0.3860 - val_loss: 4.5042 - val_accuracy: 0.2450
# Epoch 33/100
# 58/63 [==========================>...] - ETA: 0s - loss: 2.8441 - accuracy: 0.4100
# Epoch 33: val_loss did not improve from 4.50419
# 63/63 [==============================] - 0s 2ms/step - loss: 2.8491 - accuracy: 0.4060 - val_loss: 4.8402 - val_accuracy: 0.1800
# Epoch 34/100
# 57/63 [==========================>...] - ETA: 0s - loss: 2.5883 - accuracy: 0.4084
# Epoch 34: val_loss improved from 4.50419 to 4.08361, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 2.5828 - accuracy: 0.4055 - val_loss: 4.0836 - val_accuracy: 0.2350
# Epoch 35/100
# 58/63 [==========================>...] - ETA: 0s - loss: 2.7114 - accuracy: 0.4041
# Epoch 35: val_loss did not improve from 4.08361
# 63/63 [==============================] - 0s 2ms/step - loss: 2.7431 - accuracy: 0.4040 - val_loss: 5.0024 - val_accuracy: 0.2500
# Epoch 36/100
# 56/63 [=========================>....] - ETA: 0s - loss: 2.7537 - accuracy: 0.4023
# Epoch 36: val_loss improved from 4.08361 to 3.72653, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 2.7450 - accuracy: 0.4070 - val_loss: 3.7265 - val_accuracy: 0.3250
# Epoch 37/100
# 58/63 [==========================>...] - ETA: 0s - loss: 2.8530 - accuracy: 0.3879
# Epoch 37: val_loss did not improve from 3.72653
# 63/63 [==============================] - 0s 2ms/step - loss: 2.8775 - accuracy: 0.3875 - val_loss: 4.4316 - val_accuracy: 0.2850
# Epoch 38/100
# 57/63 [==========================>...] - ETA: 0s - loss: 2.7269 - accuracy: 0.4052
# Epoch 38: val_loss did not improve from 3.72653
# 63/63 [==============================] - 0s 2ms/step - loss: 2.7202 - accuracy: 0.4085 - val_loss: 4.4278 - val_accuracy: 0.2550
# Epoch 39/100
# 58/63 [==========================>...] - ETA: 0s - loss: 2.3007 - accuracy: 0.4671
# Epoch 39: val_loss improved from 3.72653 to 3.29245, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 2.3037 - accuracy: 0.4685 - val_loss: 3.2924 - val_accuracy: 0.2950
# Epoch 40/100
# 59/63 [===========================>..] - ETA: 0s - loss: 2.3402 - accuracy: 0.4412
# Epoch 40: val_loss improved from 3.29245 to 3.10415, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 2ms/step - loss: 2.3425 - accuracy: 0.4415 - val_loss: 3.1041 - val_accuracy: 0.3400
# Epoch 41/100
# 59/63 [===========================>..] - ETA: 0s - loss: 2.3188 - accuracy: 0.4497
# Epoch 41: val_loss did not improve from 3.10415
# 63/63 [==============================] - 0s 2ms/step - loss: 2.3096 - accuracy: 0.4500 - val_loss: 3.2472 - val_accuracy: 0.3200
# Epoch 42/100
# 57/63 [==========================>...] - ETA: 0s - loss: 2.3273 - accuracy: 0.4529
# Epoch 42: val_loss improved from 3.10415 to 3.07494, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 2.3077 - accuracy: 0.4540 - val_loss: 3.0749 - val_accuracy: 0.3550
# Epoch 43/100
# 53/63 [========================>.....] - ETA: 0s - loss: 2.1139 - accuracy: 0.4805
# Epoch 43: val_loss did not improve from 3.07494
# 63/63 [==============================] - 0s 3ms/step - loss: 2.0960 - accuracy: 0.4845 - val_loss: 3.2638 - val_accuracy: 0.3550
# Epoch 44/100
# 53/63 [========================>.....] - ETA: 0s - loss: 2.0444 - accuracy: 0.4699
# Epoch 44: val_loss improved from 3.07494 to 2.90560, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 2.0407 - accuracy: 0.4775 - val_loss: 2.9056 - val_accuracy: 0.3800
# Epoch 45/100
# 55/63 [=========================>....] - ETA: 0s - loss: 2.0534 - accuracy: 0.4824
# Epoch 45: val_loss improved from 2.90560 to 2.74971, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 2.0845 - accuracy: 0.4770 - val_loss: 2.7497 - val_accuracy: 0.4000
# Epoch 46/100
# 53/63 [========================>.....] - ETA: 0s - loss: 2.0372 - accuracy: 0.4929
# Epoch 46: val_loss improved from 2.74971 to 2.67690, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 2.0571 - accuracy: 0.4885 - val_loss: 2.6769 - val_accuracy: 0.4200
# Epoch 47/100
# 38/63 [=================>............] - ETA: 0s - loss: 1.9088 - accuracy: 0.5082
# Epoch 47: val_loss did not improve from 2.67690
# 63/63 [==============================] - 0s 3ms/step - loss: 1.9845 - accuracy: 0.4945 - val_loss: 2.7581 - val_accuracy: 0.4000
# Epoch 48/100
# 50/63 [======================>.......] - ETA: 0s - loss: 1.9216 - accuracy: 0.5019
# Epoch 48: val_loss improved from 2.67690 to 2.42043, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 1.9206 - accuracy: 0.4960 - val_loss: 2.4204 - val_accuracy: 0.3850
# Epoch 49/100
# 62/63 [============================>.] - ETA: 0s - loss: 1.8969 - accuracy: 0.5101
# Epoch 49: val_loss did not improve from 2.42043
# 63/63 [==============================] - 0s 2ms/step - loss: 1.8943 - accuracy: 0.5105 - val_loss: 2.4996 - val_accuracy: 0.4250
# Epoch 50/100
# 62/63 [============================>.] - ETA: 0s - loss: 1.8558 - accuracy: 0.5197
# Epoch 50: val_loss did not improve from 2.42043
# 63/63 [==============================] - 0s 2ms/step - loss: 1.8620 - accuracy: 0.5180 - val_loss: 3.1022 - val_accuracy: 0.3350
# Epoch 51/100
# 61/63 [============================>.] - ETA: 0s - loss: 1.8384 - accuracy: 0.5113
# Epoch 51: val_loss did not improve from 2.42043
# 63/63 [==============================] - 0s 2ms/step - loss: 1.8274 - accuracy: 0.5135 - val_loss: 2.6172 - val_accuracy: 0.4100
# Epoch 52/100
# 59/63 [===========================>..] - ETA: 0s - loss: 1.7816 - accuracy: 0.5164
# Epoch 52: val_loss improved from 2.42043 to 2.18833, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 1.7759 - accuracy: 0.5175 - val_loss: 2.1883 - val_accuracy: 0.4450
# Epoch 53/100
# 58/63 [==========================>...] - ETA: 0s - loss: 1.7436 - accuracy: 0.5431
# Epoch 53: val_loss did not improve from 2.18833
# 63/63 [==============================] - 0s 2ms/step - loss: 1.7413 - accuracy: 0.5420 - val_loss: 3.0041 - val_accuracy: 0.3450
# Epoch 54/100
# 60/63 [===========================>..] - ETA: 0s - loss: 1.7541 - accuracy: 0.5339
# Epoch 54: val_loss did not improve from 2.18833
# 63/63 [==============================] - 0s 2ms/step - loss: 1.7542 - accuracy: 0.5320 - val_loss: 2.4239 - val_accuracy: 0.3800
# Epoch 55/100
# 58/63 [==========================>...] - ETA: 0s - loss: 1.6157 - accuracy: 0.5544
# Epoch 55: val_loss did not improve from 2.18833
# 63/63 [==============================] - 0s 2ms/step - loss: 1.6410 - accuracy: 0.5470 - val_loss: 2.4099 - val_accuracy: 0.3950
# Epoch 56/100
# 61/63 [============================>.] - ETA: 0s - loss: 1.7221 - accuracy: 0.5420
# Epoch 56: val_loss improved from 2.18833 to 2.15739, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 2ms/step - loss: 1.7309 - accuracy: 0.5400 - val_loss: 2.1574 - val_accuracy: 0.4350
# Epoch 57/100
# 60/63 [===========================>..] - ETA: 0s - loss: 1.6140 - accuracy: 0.5443
# Epoch 57: val_loss did not improve from 2.15739
# 63/63 [==============================] - 0s 2ms/step - loss: 1.6150 - accuracy: 0.5490 - val_loss: 2.3672 - val_accuracy: 0.4100
# Epoch 58/100
# 57/63 [==========================>...] - ETA: 0s - loss: 1.7064 - accuracy: 0.5461
# Epoch 58: val_loss did not improve from 2.15739
# 63/63 [==============================] - 0s 2ms/step - loss: 1.7201 - accuracy: 0.5425 - val_loss: 2.7253 - val_accuracy: 0.3650
# Epoch 59/100
# 57/63 [==========================>...] - ETA: 0s - loss: 1.5878 - accuracy: 0.5565
# Epoch 59: val_loss did not improve from 2.15739
# 63/63 [==============================] - 0s 2ms/step - loss: 1.6170 - accuracy: 0.5535 - val_loss: 2.1612 - val_accuracy: 0.3950
# Epoch 60/100
# 57/63 [==========================>...] - ETA: 0s - loss: 1.6489 - accuracy: 0.5345
# Epoch 60: val_loss did not improve from 2.15739
# 63/63 [==============================] - 0s 2ms/step - loss: 1.6486 - accuracy: 0.5350 - val_loss: 2.2918 - val_accuracy: 0.4100
# Epoch 61/100
# 59/63 [===========================>..] - ETA: 0s - loss: 1.5737 - accuracy: 0.5673
# Epoch 61: val_loss did not improve from 2.15739
# 63/63 [==============================] - 0s 2ms/step - loss: 1.6107 - accuracy: 0.5600 - val_loss: 2.2929 - val_accuracy: 0.4300
# Epoch 62/100
# 57/63 [==========================>...] - ETA: 0s - loss: 1.6127 - accuracy: 0.5488
# Epoch 62: val_loss improved from 2.15739 to 2.13957, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 1.6355 - accuracy: 0.5440 - val_loss: 2.1396 - val_accuracy: 0.4600
# Epoch 63/100
# 58/63 [==========================>...] - ETA: 0s - loss: 1.5920 - accuracy: 0.5544
# Epoch 63: val_loss improved from 2.13957 to 2.02456, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 1.5858 - accuracy: 0.5600 - val_loss: 2.0246 - val_accuracy: 0.4600
# Epoch 64/100
# 57/63 [==========================>...] - ETA: 0s - loss: 1.5433 - accuracy: 0.5647
# Epoch 64: val_loss did not improve from 2.02456
# 63/63 [==============================] - 0s 2ms/step - loss: 1.5656 - accuracy: 0.5590 - val_loss: 2.0484 - val_accuracy: 0.4550
# Epoch 65/100
# 57/63 [==========================>...] - ETA: 0s - loss: 1.5401 - accuracy: 0.5740
# Epoch 65: val_loss did not improve from 2.02456
# 63/63 [==============================] - 0s 2ms/step - loss: 1.5838 - accuracy: 0.5635 - val_loss: 2.2073 - val_accuracy: 0.4600
# Epoch 66/100
# 55/63 [=========================>....] - ETA: 0s - loss: 1.7235 - accuracy: 0.5369
# Epoch 66: val_loss did not improve from 2.02456
# 63/63 [==============================] - 0s 2ms/step - loss: 1.7331 - accuracy: 0.5330 - val_loss: 2.4518 - val_accuracy: 0.4150
# Epoch 67/100
# 53/63 [========================>.....] - ETA: 0s - loss: 1.6759 - accuracy: 0.5495
# Epoch 67: val_loss did not improve from 2.02456
# 63/63 [==============================] - 0s 3ms/step - loss: 1.6920 - accuracy: 0.5450 - val_loss: 2.3252 - val_accuracy: 0.4400
# Epoch 68/100
# 53/63 [========================>.....] - ETA: 0s - loss: 1.5577 - accuracy: 0.5755
# Epoch 68: val_loss improved from 2.02456 to 2.00843, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 1.5625 - accuracy: 0.5735 - val_loss: 2.0084 - val_accuracy: 0.4850
# Epoch 69/100
# 51/63 [=======================>......] - ETA: 0s - loss: 1.4484 - accuracy: 0.6005
# Epoch 69: val_loss did not improve from 2.00843
# 63/63 [==============================] - 0s 3ms/step - loss: 1.4876 - accuracy: 0.5875 - val_loss: 2.2349 - val_accuracy: 0.4350
# Epoch 70/100
# 52/63 [=======================>......] - ETA: 0s - loss: 1.5306 - accuracy: 0.5649
# Epoch 70: val_loss did not improve from 2.00843
# 63/63 [==============================] - 0s 3ms/step - loss: 1.5532 - accuracy: 0.5610 - val_loss: 2.3364 - val_accuracy: 0.4300
# Epoch 71/100
# 54/63 [========================>.....] - ETA: 0s - loss: 1.5316 - accuracy: 0.5932
# Epoch 71: val_loss did not improve from 2.00843
# 63/63 [==============================] - 0s 3ms/step - loss: 1.5314 - accuracy: 0.5865 - val_loss: 2.0306 - val_accuracy: 0.4800
# Epoch 72/100
# 51/63 [=======================>......] - ETA: 0s - loss: 1.5566 - accuracy: 0.5631
# Epoch 72: val_loss did not improve from 2.00843
# 63/63 [==============================] - 0s 3ms/step - loss: 1.5613 - accuracy: 0.5610 - val_loss: 2.3469 - val_accuracy: 0.4500
# Epoch 73/100
# 56/63 [=========================>....] - ETA: 0s - loss: 1.5590 - accuracy: 0.5698
# Epoch 73: val_loss did not improve from 2.00843
# 63/63 [==============================] - 0s 2ms/step - loss: 1.5635 - accuracy: 0.5660 - val_loss: 2.2048 - val_accuracy: 0.4600
# Epoch 74/100
# 53/63 [========================>.....] - ETA: 0s - loss: 1.5158 - accuracy: 0.5767
# Epoch 74: val_loss did not improve from 2.00843
# 63/63 [==============================] - 0s 3ms/step - loss: 1.5542 - accuracy: 0.5720 - val_loss: 2.4603 - val_accuracy: 0.4200
# Epoch 75/100
# 54/63 [========================>.....] - ETA: 0s - loss: 1.6805 - accuracy: 0.5475
# Epoch 75: val_loss did not improve from 2.00843
# 63/63 [==============================] - 0s 3ms/step - loss: 1.6537 - accuracy: 0.5525 - val_loss: 2.3053 - val_accuracy: 0.4500
# Epoch 76/100
# 55/63 [=========================>....] - ETA: 0s - loss: 1.5416 - accuracy: 0.5597
# Epoch 76: val_loss did not improve from 2.00843
# 63/63 [==============================] - 0s 3ms/step - loss: 1.5493 - accuracy: 0.5560 - val_loss: 2.3116 - val_accuracy: 0.4500
# Epoch 77/100
# 55/63 [=========================>....] - ETA: 0s - loss: 1.5873 - accuracy: 0.5528
# Epoch 77: val_loss did not improve from 2.00843
# 63/63 [==============================] - 0s 2ms/step - loss: 1.5894 - accuracy: 0.5530 - val_loss: 2.1621 - val_accuracy: 0.4700
# Epoch 78/100
# 53/63 [========================>.....] - ETA: 0s - loss: 1.5633 - accuracy: 0.5654
# Epoch 78: val_loss improved from 2.00843 to 1.95586, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 1.5763 - accuracy: 0.5645 - val_loss: 1.9559 - val_accuracy: 0.5200
# Epoch 79/100
# 57/63 [==========================>...] - ETA: 0s - loss: 1.5871 - accuracy: 0.5548
# Epoch 79: val_loss did not improve from 1.95586
# 63/63 [==============================] - 0s 2ms/step - loss: 1.5853 - accuracy: 0.5540 - val_loss: 2.7490 - val_accuracy: 0.3750
# Epoch 80/100
# 55/63 [=========================>....] - ETA: 0s - loss: 1.6364 - accuracy: 0.5562
# Epoch 80: val_loss did not improve from 1.95586
# 63/63 [==============================] - 0s 2ms/step - loss: 1.6328 - accuracy: 0.5565 - val_loss: 2.0766 - val_accuracy: 0.4350
# Epoch 81/100
# 55/63 [=========================>....] - ETA: 0s - loss: 1.6295 - accuracy: 0.5614
# Epoch 81: val_loss did not improve from 1.95586
# 63/63 [==============================] - 0s 3ms/step - loss: 1.6443 - accuracy: 0.5560 - val_loss: 2.1959 - val_accuracy: 0.4450
# Epoch 82/100
# 51/63 [=======================>......] - ETA: 0s - loss: 1.5998 - accuracy: 0.5570
# Epoch 82: val_loss did not improve from 1.95586
# 63/63 [==============================] - 0s 3ms/step - loss: 1.6015 - accuracy: 0.5585 - val_loss: 2.1628 - val_accuracy: 0.5000
# Epoch 83/100
# 58/63 [==========================>...] - ETA: 0s - loss: 1.6667 - accuracy: 0.5393
# Epoch 83: val_loss did not improve from 1.95586
# 63/63 [==============================] - 0s 2ms/step - loss: 1.6775 - accuracy: 0.5385 - val_loss: 2.0506 - val_accuracy: 0.4500
# Epoch 84/100
# 51/63 [=======================>......] - ETA: 0s - loss: 1.5810 - accuracy: 0.5674
# Epoch 84: val_loss improved from 1.95586 to 1.93690, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 1.
val_loss did not improve from 1.93690
# 63/63 [==============================] - 0s 2ms/step - loss: 4.1650 - accuracy: 0.3095 - val_loss: 2.9593 - val_accuracy: 0.4450
# Epoch 31/100
# 57/63 [==========================>...] - ETA: 0s - loss: 4.0978 - accuracy: 0.3279
# Epoch 31: val_loss did not improve from 1.93690
# 63/63 [==============================] - 0s 2ms/step - loss: 4.1166 - accuracy: 0.3260 - val_loss: 2.8205 - val_accuracy: 0.4850
# Epoch 32/100
# 55/63 [=========================>....] - ETA: 0s - loss: 4.0562 - accuracy: 0.3278
# Epoch 32: val_loss did not improve from 1.93690
# 63/63 [==============================] - 0s 2ms/step - loss: 4.0877 - accuracy: 0.3245 - val_loss: 2.9272 - val_accuracy: 0.4300
# Epoch 33/100
# 57/63 [==========================>...] - ETA: 0s - loss: 3.8441 - accuracy: 0.3251
# Epoch 33: val_loss did not improve from 1.93690
# 63/63 [==============================] - 0s 2ms/step - loss: 3.7992 - accuracy: 0.3270 - val_loss: 2.8631 - val_accuracy: 0.4200
# Epoch 34/100
# 57/63 [==========================>...] - ETA: 0s - loss: 3.4700 - accuracy: 0.3492
# Epoch 34: val_loss did not improve from 1.93690
# 63/63 [==============================] - 0s 2ms/step - loss: 3.4626 - accuracy: 0.3540 - val_loss: 2.5414 - val_accuracy: 0.4350
# Epoch 35/100
# 57/63 [==========================>...] - ETA: 0s - loss: 2.9015 - accuracy: 0.4041
# Epoch 35: val_loss did not improve from 1.93690
# 63/63 [==============================] - 0s 2ms/step - loss: 2.9099 - accuracy: 0.4010 - val_loss: 3.2184 - val_accuracy: 0.3900
# Epoch 36/100
# 57/63 [==========================>...] - ETA: 0s - loss: 3.2158 - accuracy: 0.3865
# Epoch 36: val_loss did not improve from 1.93690
# 63/63 [==============================] - 0s 2ms/step - loss: 3.1690 - accuracy: 0.3940 - val_loss: 2.3266 - val_accuracy: 0.4950
# Epoch 37/100
# 58/63 [==========================>...] - ETA: 0s - loss: 2.8026 - accuracy: 0.4073
# Epoch 37: val_loss did not improve from 1.93690
# 63/63 [==============================] - 0s 2ms/step - loss: 2.8324 - accuracy: 0.4040 - val_loss: 2.0259 - val_accuracy: 0.5300
# Epoch 38/100
# 57/63 [==========================>...] - ETA: 0s - loss: 2.7923 - accuracy: 0.3980
# Epoch 38: val_loss did not improve from 1.93690
# 63/63 [==============================] - 0s 2ms/step - loss: 2.8056 - accuracy: 0.3975 - val_loss: 2.3016 - val_accuracy: 0.5100
# Epoch 39/100
# 56/63 [=========================>....] - ETA: 0s - loss: 2.6980 - accuracy: 0.4224
# Epoch 39: val_loss did not improve from 1.93690
# 63/63 [==============================] - 0s 2ms/step - loss: 2.6731 - accuracy: 0.4220 - val_loss: 2.4143 - val_accuracy: 0.4950
# Epoch 40/100
# 57/63 [==========================>...] - ETA: 0s - loss: 2.3501 - accuracy: 0.4479
# Epoch 40: val_loss did not improve from 1.93690
# 63/63 [==============================] - 0s 2ms/step - loss: 2.3290 - accuracy: 0.4505 - val_loss: 2.0210 - val_accuracy: 0.5500
# Epoch 41/100
# 46/63 [====================>.........] - ETA: 0s - loss: 2.3926 - accuracy: 0.4470
# Epoch 41: val_loss improved from 1.93690 to 1.82895, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 2.4162 - accuracy: 0.4375 - val_loss: 1.8290 - val_accuracy: 0.5550
# Epoch 42/100
# 54/63 [========================>.....] - ETA: 0s - loss: 2.5915 - accuracy: 0.4161
# Epoch 42: val_loss did not improve from 1.82895
# 63/63 [==============================] - 0s 3ms/step - loss: 2.5809 - accuracy: 0.4180 - val_loss: 2.1598 - val_accuracy: 0.5250
# Epoch 43/100
# 58/63 [==========================>...] - ETA: 0s - loss: 2.2607 - accuracy: 0.4461
# Epoch 43: val_loss improved from 1.82895 to 1.78905, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 2.2630 - accuracy: 0.4460 - val_loss: 1.7890 - val_accuracy: 0.5250
# Epoch 44/100
# 58/63 [==========================>...] - ETA: 0s - loss: 2.1417 - accuracy: 0.4758
# Epoch 44: val_loss did not improve from 1.78905
# 63/63 [==============================] - 0s 2ms/step - loss: 2.1556 - accuracy: 0.4715 - val_loss: 2.0409 - val_accuracy: 0.4950
# Epoch 45/100
# 56/63 [=========================>....] - ETA: 0s - loss: 2.3206 - accuracy: 0.4537
# Epoch 45: val_loss did not improve from 1.78905
# 63/63 [==============================] - 0s 2ms/step - loss: 2.3223 - accuracy: 0.4540 - val_loss: 2.2245 - val_accuracy: 0.4800
# Epoch 46/100
# 57/63 [==========================>...] - ETA: 0s - loss: 2.2913 - accuracy: 0.4594
# Epoch 46: val_loss improved from 1.78905 to 1.77190, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 2.3172 - accuracy: 0.4530 - val_loss: 1.7719 - val_accuracy: 0.5050
# Epoch 47/100
# 57/63 [==========================>...] - ETA: 0s - loss: 2.3590 - accuracy: 0.4578
# Epoch 47: val_loss did not improve from 1.77190
# 63/63 [==============================] - 0s 2ms/step - loss: 2.3232 - accuracy: 0.4610 - val_loss: 2.0158 - val_accuracy: 0.5200
# Epoch 48/100
# 56/63 [=========================>....] - ETA: 0s - loss: 1.9847 - accuracy: 0.5028
# Epoch 48: val_loss did not improve from 1.77190
# 63/63 [==============================] - 0s 2ms/step - loss: 2.0015 - accuracy: 0.4965 - val_loss: 1.7808 - val_accuracy: 0.5200
# Epoch 49/100
# 56/63 [=========================>....] - ETA: 0s - loss: 2.1462 - accuracy: 0.4743
# Epoch 49: val_loss improved from 1.77190 to 1.74492, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 2.1505 - accuracy: 0.4765 - val_loss: 1.7449 - val_accuracy: 0.5550
# Epoch 50/100
# 56/63 [=========================>....] - ETA: 0s - loss: 2.0358 - accuracy: 0.4900
# Epoch 50: val_loss improved from 1.74492 to 1.65472, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 2.0412 - accuracy: 0.4925 - val_loss: 1.6547 - val_accuracy: 0.5700
# Epoch 51/100
# 56/63 [=========================>....] - ETA: 0s - loss: 1.9258 - accuracy: 0.5039
# Epoch 51: val_loss improved from 1.65472 to 1.55329, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 1.9028 - accuracy: 0.5075 - val_loss: 1.5533 - val_accuracy: 0.5950
# Epoch 52/100
# 58/63 [==========================>...] - ETA: 0s - loss: 1.8309 - accuracy: 0.5167
# Epoch 52: val_loss improved from 1.55329 to 1.41281, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 1.8320 - accuracy: 0.5185 - val_loss: 1.4128 - val_accuracy: 0.6100
# Epoch 53/100
# 56/63 [=========================>....] - ETA: 0s - loss: 1.8380 - accuracy: 0.5229
# Epoch 53: val_loss did not improve from 1.41281
# 63/63 [==============================] - 0s 2ms/step - loss: 1.8182 - accuracy: 0.5255 - val_loss: 1.5528 - val_accuracy: 0.6300
# Epoch 54/100
# 56/63 [=========================>....] - ETA: 0s - loss: 1.8757 - accuracy: 0.4994
# Epoch 54: val_loss improved from 1.41281 to 1.37559, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 1.9196 - accuracy: 0.4950 - val_loss: 1.3756 - val_accuracy: 0.6350
# Epoch 55/100
# 58/63 [==========================>...] - ETA: 0s - loss: 1.7935 - accuracy: 0.5162
# Epoch 55: val_loss did not improve from 1.37559
# 63/63 [==============================] - 0s 3ms/step - loss: 1.7990 - accuracy: 0.5180 - val_loss: 1.4809 - val_accuracy: 0.5950
# Epoch 56/100
# 50/63 [======================>.......] - ETA: 0s - loss: 1.7719 - accuracy: 0.5219
# Epoch 56: val_loss did not improve from 1.37559
# 63/63 [==============================] - 0s 3ms/step - loss: 1.8047 - accuracy: 0.5220 - val_loss: 1.5931 - val_accuracy: 0.5750
# Epoch 57/100
# 56/63 [=========================>....] - ETA: 0s - loss: 1.7188 - accuracy: 0.5273
# Epoch 57: val_loss did not improve from 1.37559
# 63/63 [==============================] - 0s 2ms/step - loss: 1.7156 - accuracy: 0.5260 - val_loss: 1.6197 - val_accuracy: 0.5800
# Epoch 58/100
# 56/63 [=========================>....] - ETA: 0s - loss: 1.7948 - accuracy: 0.5195
# Epoch 58: val_loss did not improve from 1.37559
# 63/63 [==============================] - 0s 2ms/step - loss: 1.7641 - accuracy: 0.5275 - val_loss: 1.7034 - val_accuracy: 0.6200
# Epoch 59/100
# 56/63 [=========================>....] - ETA: 0s - loss: 1.7280 - accuracy: 0.5368
# Epoch 59: val_loss did not improve from 1.37559
# 63/63 [==============================] - 0s 2ms/step - loss: 1.7023 - accuracy: 0.5390 - val_loss: 1.4898 - val_accuracy: 0.6050
# Epoch 60/100
# 55/63 [=========================>....] - ETA: 0s - loss: 1.6568 - accuracy: 0.5449
# Epoch 60: val_loss did not improve from 1.37559
# 63/63 [==============================] - 0s 2ms/step - loss: 1.6825 - accuracy: 0.5415 - val_loss: 1.5043 - val_accuracy: 0.6150
# Epoch 61/100
# 56/63 [=========================>....] - ETA: 0s - loss: 1.8204 - accuracy: 0.5134
# Epoch 61: val_loss did not improve from 1.37559
# 63/63 [==============================] - 0s 2ms/step - loss: 1.8123 - accuracy: 0.5125 - val_loss: 1.5353 - val_accuracy: 0.5750
# Epoch 62/100
# 57/63 [==========================>...] - ETA: 0s - loss: 1.6940 - accuracy: 0.5345
# Epoch 62: val_loss improved from 1.37559 to 1.27833, saving model to saved_models\audio_classification.hdf5
# 63/63 [==============================] - 0s 3ms/step - loss: 1.6891 - accuracy: 0.5380 - val_loss: 1.2783 - val_accuracy: 0.6150
# Epoch 63/100
# 56/63 [=========================>....] - ETA: 0s - loss: 1.8063 - accuracy: 0.5078
# Epoch 63: val_loss did not improve from 1.27833
# 63/63 [==============================] - 0s 2ms/step - loss: 1.7664 - accuracy: 0.5180 - val_loss: 1.3808 - val_accuracy: 0.6100
# Epoch 64/100
# 58/63 [==========================>...] - ETA: 0s - loss: 1.5965 - accuracy: 0.5523
# Epoch 64: val_loss did not improve from 1.27833
# 63/63 [==============================] - 0s 2ms/step - loss: 1.5939 - accuracy: 0.5515 - val_loss: 1.3397 - val_accuracy: 0.6200
# Epoch 65/100
# 56/63 [=========================>....] - ETA: 0s - loss: 1.6297 - accuracy: 0.5541
# Epoch 65: val_loss did not improve from 1.27833
# ...
# Epoch 43/100
# 54/63 [========================>.....] - ETA: 0s - loss: 2.4362 - accuracy: 0.4439
# Epoch 43: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 2.4856 - accuracy: 0.4365 - val_loss: 3.1956 - val_accuracy: 0.3900
# Epoch 44/100
# 55/63 [=========================>....] - ETA: 0s - loss: 2.3667 - accuracy: 0.4409
# Epoch 44: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 2ms/step - loss: 2.4144 - accuracy: 0.4395 - val_loss: 3.4407 - val_accuracy: 0.3550
# Epoch 45/100
# 54/63 [========================>.....] - ETA: 0s - loss: 2.1893 - accuracy: 0.4757
# Epoch 45: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 2ms/step - loss: 2.1985 - accuracy: 0.4775 - val_loss: 2.7162 - val_accuracy: 0.4100
# Epoch 46/100
# 63/63 [==============================] - ETA: 0s - loss: 2.1111 - accuracy: 0.4800
# Epoch 46: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 2.1111 - accuracy: 0.4800 - val_loss: 3.1893 - val_accuracy: 0.3750
# Epoch 47/100
# 55/63 [=========================>....] - ETA: 0s - loss: 2.1865 - accuracy: 0.4665
# Epoch 47: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 2ms/step - loss: 2.1995 - accuracy: 0.4635 - val_loss: 3.0246 - val_accuracy: 0.3950
# Epoch 48/100
# 60/63 [===========================>..] - ETA: 0s - loss: 2.2631 - accuracy: 0.4630
# Epoch 48: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 2ms/step - loss: 2.2415 - accuracy: 0.4680 - val_loss: 2.7236 - val_accuracy: 0.4350
# Epoch 49/100
# 56/63 [=========================>....] - ETA: 0s - loss: 2.0201 - accuracy: 0.5017
# Epoch 49: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 2ms/step - loss: 1.9871 - accuracy: 0.5035 - val_loss: 3.1370 - val_accuracy: 0.3900
# Epoch 50/100
# 53/63 [========================>.....] - ETA: 0s - loss: 1.9587 - accuracy: 0.5047
# Epoch 50: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.9679 - accuracy: 0.4990 - val_loss: 3.2972 - val_accuracy: 0.3750
# Epoch 51/100
# 53/63 [========================>.....] - ETA: 0s - loss: 1.9664 - accuracy: 0.5018
# Epoch 51: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.9685 - accuracy: 0.4995 - val_loss: 2.8139 - val_accuracy: 0.4050
# Epoch 52/100
# 52/63 [=======================>......] - ETA: 0s - loss: 2.1301 - accuracy: 0.4784
# Epoch 52: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 2.1326 - accuracy: 0.4735 - val_loss: 3.0949 - val_accuracy: 0.3750
# Epoch 53/100
# 51/63 [=======================>......] - ETA: 0s - loss: 1.9904 - accuracy: 0.5074
# Epoch 53: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.9556 - accuracy: 0.5125 - val_loss: 2.7524 - val_accuracy: 0.4300
# Epoch 54/100
# 50/63 [======================>.......] - ETA: 0s - loss: 1.8634 - accuracy: 0.5238
# Epoch 54: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.8965 - accuracy: 0.5145 - val_loss: 2.7522 - val_accuracy: 0.4550
# Epoch 55/100
# 52/63 [=======================>......] - ETA: 0s - loss: 1.8785 - accuracy: 0.5114
# Epoch 55: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.8760 - accuracy: 0.5140 - val_loss: 2.7533 - val_accuracy: 0.4150
# Epoch 56/100
# 52/63 [=======================>......] - ETA: 0s - loss: 1.9395 - accuracy: 0.5174
# Epoch 56: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.9767 - accuracy: 0.5120 - val_loss: 2.5896 - val_accuracy: 0.4500
# Epoch 57/100
# 56/63 [=========================>....] - ETA: 0s - loss: 1.8217 - accuracy: 0.5374
# Epoch 57: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 2ms/step - loss: 1.8558 - accuracy: 0.5310 - val_loss: 2.7922 - val_accuracy: 0.4400
# Epoch 58/100
# 55/63 [=========================>....] - ETA: 0s - loss: 1.9046 - accuracy: 0.4960
# Epoch 58: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.9086 - accuracy: 0.5005 - val_loss: 2.8821 - val_accuracy: 0.4250
# Epoch 59/100
# 52/63 [=======================>......] - ETA: 0s - loss: 1.8116 - accuracy: 0.5246
# Epoch 59: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.7992 - accuracy: 0.5255 - val_loss: 2.9714 - val_accuracy: 0.4100
# Epoch 60/100
# 55/63 [=========================>....] - ETA: 0s - loss: 1.7278 - accuracy: 0.5369
# Epoch 60: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 2ms/step - loss: 1.7514 - accuracy: 0.5300 - val_loss: 2.6045 - val_accuracy: 0.4500
# Epoch 61/100
# 57/63 [==========================>...] - ETA: 0s - loss: 1.7650 - accuracy: 0.5340
# Epoch 61: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 2ms/step - loss: 1.7927 - accuracy: 0.5320 - val_loss: 2.7203 - val_accuracy: 0.3950
# Epoch 62/100
# 56/63 [=========================>....] - ETA: 0s - loss: 1.7340 - accuracy: 0.5335
# Epoch 62: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.7039 - accuracy: 0.5365 - val_loss: 2.6576 - val_accuracy: 0.4950
# Epoch 63/100
# 51/63 [=======================>......] - ETA: 0s - loss: 1.6835 - accuracy: 0.5551
# Epoch 63: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.6992 - accuracy: 0.5480 - val_loss: 2.4387 - val_accuracy: 0.5000
# Epoch 64/100
# 52/63 [=======================>......] - ETA: 0s - loss: 1.7195 - accuracy: 0.5409
# Epoch 64: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.7611 - accuracy: 0.5320 - val_loss: 3.0193 - val_accuracy: 0.4000
# Epoch 65/100
# 59/63 [===========================>..] - ETA: 0s - loss: 1.7876 - accuracy: 0.5323
# Epoch 65: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.7825 - accuracy: 0.5290 - val_loss: 2.7927 - val_accuracy: 0.4250
# Epoch 66/100
# 54/63 [========================>.....] - ETA: 0s - loss: 1.7865 - accuracy: 0.5237
# Epoch 66: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 2ms/step - loss: 1.7774 - accuracy: 0.5230 - val_loss: 2.8206 - val_accuracy: 0.4400
# Epoch 67/100
# 56/63 [=========================>....] - ETA: 0s - loss: 1.6974 - accuracy: 0.5268
# Epoch 67: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.6989 - accuracy: 0.5305 - val_loss: 2.8626 - val_accuracy: 0.4300
# Epoch 68/100
# 53/63 [========================>.....] - ETA: 0s - loss: 1.6904 - accuracy: 0.5578
# Epoch 68: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.7009 - accuracy: 0.5500 - val_loss: 2.9026 - val_accuracy: 0.3850
# Epoch 69/100
# 52/63 [=======================>......] - ETA: 0s - loss: 1.7984 - accuracy: 0.5288
# Epoch 69: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.7892 - accuracy: 0.5285 - val_loss: 2.8979 - val_accuracy: 0.4050
# Epoch 70/100
# 51/63 [=======================>......] - ETA: 0s - loss: 1.8376 - accuracy: 0.5276
# Epoch 70: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.8392 - accuracy: 0.5235 - val_loss: 2.5833 - val_accuracy: 0.4150
# Epoch 71/100
# 44/63 [===================>..........] - ETA: 0s - loss: 1.5733 - accuracy: 0.5653
# Epoch 71: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.6473 - accuracy: 0.5515 - val_loss: 2.4184 - val_accuracy: 0.4400
# Epoch 72/100
# 54/63 [========================>.....] - ETA: 0s - loss: 1.7192 - accuracy: 0.5295
# Epoch 72: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.7180 - accuracy: 0.5335 - val_loss: 2.6238 - val_accuracy: 0.4650
# Epoch 73/100
# 55/63 [=========================>....] - ETA: 0s - loss: 1.6473 - accuracy: 0.5574
# Epoch 73: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.6576 - accuracy: 0.5565 - val_loss: 2.8658 - val_accuracy: 0.4050
# Epoch 74/100
# 56/63 [=========================>....] - ETA: 0s - loss: 1.6160 - accuracy: 0.5642
# Epoch 74: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.6483 - accuracy: 0.5600 - val_loss: 2.8743 - val_accuracy: 0.4400
# Epoch 75/100
# 54/63 [========================>.....] - ETA: 0s - loss: 1.7757 - accuracy: 0.5399
# Epoch 75: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.7754 - accuracy: 0.5350 - val_loss: 2.6688 - val_accuracy: 0.4550
# Epoch 76/100
# 55/63 [=========================>....] - ETA: 0s - loss: 1.6996 - accuracy: 0.5324
# Epoch 76: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.7120 - accuracy: 0.5315 - val_loss: 2.6130 - val_accuracy: 0.4550
# Epoch 77/100
# 55/63 [=========================>....] - ETA: 0s - loss: 1.7158 - accuracy: 0.5511
# Epoch 77: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.7066 - accuracy: 0.5470 - val_loss: 2.7962 - val_accuracy: 0.4100
# Epoch 78/100
# 42/63 [===================>..........] - ETA: 0s - loss: 1.6103 - accuracy: 0.5833
# Epoch 78: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.6669 - accuracy: 0.5630 - val_loss: 2.7393 - val_accuracy: 0.4150
# Epoch 79/100
# 55/63 [=========================>....] - ETA: 0s - loss: 1.6163 - accuracy: 0.5597
# Epoch 79: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.6331 - accuracy: 0.5520 - val_loss: 2.4988 - val_accuracy: 0.4350
# Epoch 80/100
# 55/63 [=========================>....] - ETA: 0s - loss: 1.5726 - accuracy: 0.5722
# Epoch 80: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.5965 - accuracy: 0.5700 - val_loss: 2.6525 - val_accuracy: 0.3850
# Epoch 81/100
# 55/63 [=========================>....] - ETA: 0s - loss: 1.5897 - accuracy: 0.5574
# Epoch 81: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.6061 - accuracy: 0.5570 - val_loss: 2.7269 - val_accuracy: 0.4150
# Epoch 82/100
# 54/63 [========================>.....] - ETA: 0s - loss: 1.6435 - accuracy: 0.5480
# Epoch 82: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.6511 - accuracy: 0.5450 - val_loss: 2.6979 - val_accuracy: 0.4550
# Epoch 83/100
# 55/63 [=========================>....] - ETA: 0s - loss: 1.6096 - accuracy: 0.5619
# Epoch 83: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.6015 - accuracy: 0.5620 - val_loss: 2.5900 - val_accuracy: 0.4200
# Epoch 84/100
# 43/63 [===================>..........] - ETA: 0s - loss: 1.6845 - accuracy: 0.5458
# Epoch 84: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.6648 - accuracy: 0.5440 - val_loss: 2.9573 - val_accuracy: 0.4200
# Epoch 85/100
# 54/63 [========================>.....] - ETA: 0s - loss: 1.5851 - accuracy: 0.5856
# Epoch 85: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.6138 - accuracy: 0.5775 - val_loss: 2.6510 - val_accuracy: 0.4450
# Epoch 86/100
# 55/63 [=========================>....] - ETA: 0s - loss: 1.7219 - accuracy: 0.5426
# Epoch 86: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 2ms/step - loss: 1.7142 - accuracy: 0.5445 - val_loss: 2.9457 - val_accuracy: 0.4400
# Epoch 87/100
# 54/63 [========================>.....] - ETA: 0s - loss: 1.7719 - accuracy: 0.5347
# Epoch 87: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.7403 - accuracy: 0.5405 - val_loss: 3.1188 - val_accuracy: 0.4050
# Epoch 88/100
# 55/63 [=========================>....] - ETA: 0s - loss: 1.6423 - accuracy: 0.5568
# Epoch 88: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.6554 - accuracy: 0.5570 - val_loss: 2.6651 - val_accuracy: 0.4700
# Epoch 89/100
# 55/63 [=========================>....] - ETA: 0s - loss: 1.8152 - accuracy: 0.5375
# Epoch 89: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 2ms/step - loss: 1.8524 - accuracy: 0.5320 - val_loss: 2.5432 - val_accuracy: 0.4750
# Epoch 90/100
# 54/63 [========================>.....] - ETA: 0s - loss: 1.7623 - accuracy: 0.5440
# Epoch 90: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.7571 - accuracy: 0.5445 - val_loss: 2.8401 - val_accuracy: 0.4650
# Epoch 91/100
# 51/63 [=======================>......] - ETA: 0s - loss: 1.6075 - accuracy: 0.5668
# Epoch 91: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.5844 - accuracy: 0.5680 - val_loss: 2.8387 - val_accuracy: 0.3600
# Epoch 92/100
# 55/63 [=========================>....] - ETA: 0s - loss: 1.5949 - accuracy: 0.5659
# Epoch 92: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 2ms/step - loss: 1.6014 - accuracy: 0.5660 - val_loss: 2.9314 - val_accuracy: 0.4250
# Epoch 93/100
# 55/63 [=========================>....] - ETA: 0s - loss: 1.6215 - accuracy: 0.5608
# Epoch 93: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 2ms/step - loss: 1.6279 - accuracy: 0.5575 - val_loss: 2.6850 - val_accuracy: 0.4550
# Epoch 94/100
# 56/63 [=========================>....] - ETA: 0s - loss: 1.7082 - accuracy: 0.5558
# Epoch 94: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.7522 - accuracy: 0.5525 - val_loss: 2.9182 - val_accuracy: 0.4500
# Epoch 95/100
# 56/63 [=========================>....] - ETA: 0s - loss: 1.7509 - accuracy: 0.5419
# Epoch 95: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 2ms/step - loss: 1.7471 - accuracy: 0.5380 - val_loss: 3.0690 - val_accuracy: 0.4200
# Epoch 96/100
# 54/63 [========================>.....] - ETA: 0s - loss: 1.6689 - accuracy: 0.5527
# Epoch 96: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.6883 - accuracy: 0.5440 - val_loss: 3.0855 - val_accuracy: 0.4300
# Epoch 97/100
# 49/63 [======================>.......] - ETA: 0s - loss: 1.5721 - accuracy: 0.5746
# Epoch 97: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.6094 - accuracy: 0.5640 - val_loss: 3.3247 - val_accuracy: 0.3700
# Epoch 98/100
# 55/63 [=========================>....] - ETA: 0s - loss: 1.6700 - accuracy: 0.5670
# Epoch 98: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 3ms/step - loss: 1.6728 - accuracy: 0.5685 - val_loss: 2.9160 - val_accuracy: 0.4650
# Epoch 99/100
# 55/63 [=========================>....] - ETA: 0s - loss: 1.7603 - accuracy: 0.5324
# Epoch 99: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 2ms/step - loss: 1.7690 - accuracy: 0.5335 - val_loss: 2.9876 - val_accuracy: 0.4150
# Epoch 100/100
# 54/63 [========================>.....] - ETA: 0s - loss: 1.6818 - accuracy: 0.5677
# Epoch 100: val_loss did not improve from 1.08824
# 63/63 [==============================] - 0s 2ms/step - loss: 1.6906 - accuracy: 0.5615 - val_loss: 3.0160 - val_accuracy: 0.4450
# Training completed in time:  0:01:27.003083

# %%
##ACCURACY GRAPHS
# List of history objects

model_names = ['D01', 'H01', 'M01', 'M02', 'T01']

# Plot training & validation accuracy values using a for loop
for i, history in enumerate(histories):
    plt.plot(history.history['accuracy'], label='Train ')
    plt.plot(history.history['val_accuracy'], label=f'Test {model_names[i]}')

    plt.title(f'Model accuracy for {model_names[i]}')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='upper left')
    plt.show()

# %%
##LOSS GRAPHS


# Plot training & validation loss values using a for loop
for i, history in enumerate(histories):
    plt.plot(history.history['loss'], label=f'Train - Model {i+1}')
    plt.plot(history.history['val_loss'], label=f'Test - Model {i+1}')
    plt.title('Model loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
A00 = ['D01', 'H01', 'M01', 'M02', 'T01']
models = [model1, model2, model3, model4, model5]
X_tests = [X_test1, X_test2, X_test3, X_test4, X_test5]
y_tests = [y_test1, y_test2, y_test3, y_test4, y_test5]

for i, model in enumerate(models):
    test_accuracy = model.evaluate(X_tests[i], y_tests[i], verbose=0)
    print(A00[i],"::",test_accuracy[1] * 100,"%")
# Out:
# D01 :: 43.99999976158142 %
# H01 :: 66.50000214576721 %
# M01 :: 34.99999940395355 %
# M02 :: 44.999998807907104 %
# T01 :: 44.49999928474426 %

# %%
models = [model1, model2, model3, model4, model5]
X_tests = [X_test1, X_test2, X_test3, X_test4, X_test5]
y_tests = [y_test1, y_test2, y_test3, y_test4, y_test5]
model_names = ['D01', 'H01', 'M01', 'M02', 'T01']

# Iterate over models, X_tests, and y_tests using a for loop
for model, X_test, y_test, model_name in zip(models, X_tests, y_tests, model_names):
    test_accuracy = model.evaluate(X_test, y_test, verbose=0)
    print(f'{model_name}:: {test_accuracy[1] * 100}%')
# Out:
# D01:: 43.99999976158142%
# H01:: 66.50000214576721%
# M01:: 34.99999940395355%
# M02:: 44.999998807907104%
# T01:: 44.49999928474426%

# %% [markdown]
# ##################################################################################################

# %% [markdown]
# TESTTING SOME FILES

# %%
filename = "test_audio_file_1013.wav"
audio, sample_rate = librosa.load(filename, res_type='kaiser_fast')
mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
mfccs_scaled_features = np.mean(mfccs_features.T, axis=0)
mfccs_scaled_features = mfccs_scaled_features.reshape(1, -1)

# Ensure the data type is compatible with the model
mfccs_scaled_features = mfccs_scaled_features.astype(np.float32)  # or np.float64, depending on your model

# Print information
print("MFCCs Scaled Features:", mfccs_scaled_features)
print("Shape of MFCCs Scaled Features:", mfccs_scaled_features.shape)

# Make prediction
predicted_label = model.predict(mfccs_scaled_features)

# Convert predicted label to class
